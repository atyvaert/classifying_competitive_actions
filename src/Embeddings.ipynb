# %% [markdown]
# # C. Embeddings

# %% [markdown]
# In this notebook, I used word embeddings to transform my textual data into numerical represenations. For this purpose, I used the data was cleaned in the notebook 'B. Vectorization' and that can be found in the gold_data folder. Further, I use the same base classifiers and resampling techniques that I used in the previous notebook.
#
# First, I trained a Word2Vec model (both the continuous bag of words and the skipgram implementation) to transform my textual data. Then, I used Glove embeddings for text represenation. However, as I only have a limited dataset to train embedding models, I aslo used pretrained embedding models. Then, I could use these pretrained embeddings to transform my train and test set and train my models.

# %% [markdown]
# # 0. Data loading

# %%
# General Packages #
import os
import pandas as pd
import numpy as np
import string
import re
from scipy.stats import randint
import random
from collections import Counter

# Sklearn Packages #
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, StratifiedKFold, cross_val_predict, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, make_scorer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# NLTK Packages #
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob, Word
from nltk.tokenize import word_tokenize

# Import necessary libraries for handling imbalanced data
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Embedding related imports
import sys
import gensim
from gensim.models import Word2Vec, Doc2Vec
from gensim.models.phrases import Phraser, Phrases
from gensim.models import KeyedVectors
import gensim.downloader
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# Change to Working Directory with Training Data # 
os.chdir("/Users/Artur/Desktop/thesis_HIR_versie5/coding")
#os.chdir("/Users/juarel/Desktop/studies artur/thesis_HIR/coding")

# Load the preprocessed data #
df_train = pd.read_csv("./data/gold_data/train.csv", header = 0)
df_test = pd.read_csv("./data/gold_data/test.csv", header = 0)

# inspect the data
df_train.head(5)
# Out:
#        id                                           Headline category  \
# 0  194578  Head Line: US Patent granted to BASF SE (Delaw...     None
# 1  564295  Societe Generale Launches a Next-Generation Ca...     None
# 2  504138  BARCLAYS PLC Form 8.3 - EUTELSAT COMMUNICATION...     None
# 3   91379                         ASML: 4Q Earnings Snapshot     None
# 4  265750  Form 8.3 - AXA INVESTMENT MANAGERS : Booker Gr...     None
#
#                                     cleaned_headline
# 0  head u patent granted se delaware may titled c...
# 1  societe generale launch nextgeneration card in...
# 2                             plc form communication
# 3                               4q earnings snapshot
# 4                  form investment manager group plc

# %% [markdown]
# # 1. Define functions and parameters

# %% [markdown]
# Before we continue, we first define some useful functions and parameters that we use throughout this notebook. The first four functions and parameters were also used and defined in the previous notebook.
#
# 1. get_classification_metrics: Create a function that return the classification metrics for each model. The precision, recall and f1 score are all determined using the average value of all classes, without adjusting weights to these classes.
#
# 2. Define a dataframe to store the results of the different models. Moreover, also define a dictionary that stores the best parameters for each model.
#
# 3. Define the number of splits, the stratified cross validator to ensure class frequencies are considered, and the scoring metric based on the average F1 score. We use an F1 score as scoring metric as accuracy is not a good evaluation metric in our case.
#
# 4. Define a function that trains the defined model, the input data, the classifier and its parameter grid. Besides, it will also take 4 parameters as input that give more information about the model that is being trained. This is usefull for the storage of the performance of the different algorithms.

# %% [markdown]
# New functions specific to the embedding notebook:
#
# 5. Create a function to create embeddings based on a trained model.
#
# 6. Create a function to create embeddings based on a pretrained model.

# %%
# 1. Function that returns classication metrics
def get_classification_metrics(y_true, y_pred):
    
    # Calculate Model Performance Metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')


    return accuracy, precision, recall, f1

# %%
# 2. Create an empty dataframe to store the results of all the models
results_all_df = pd.DataFrame()

# Add columns for the metrics
columns = ['vectorizer', 'FS', 'classifier', 'resampling','accuracy', 'precision', 'recall', 'f1']
for col in columns:
    results_all_df[col] = 0

# create an empty dictionary to store the optimal parameters
best_params_dict = {}

# %%
# 3. Define different parameters
# Define the number of folds for cross-validation
n_splits = 5

# Initialize the stratified k-fold object
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42) # ensures class balances are kept

# Define the scoring metric
scoring = make_scorer(f1_score, average= 'macro')

# %%
# 4. Define a function to train and evaluate the different models
def perform_grid_search(name, model, param_grid, X_train, X_test, y_train, y_test,
                       vectorizer, FS, classifier, resampling):
    
    # Define a seed value
    random.seed(7)
        
    # Perform the grid search using cross-validation
    grid_search = GridSearchCV(model, param_grid, cv=skf, scoring=scoring)
    grid_search.fit(X_train, y_train)

    # Get the best model and its hyperparameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    # Store the best parameters for the current category in the dictionary
    best_params_dict[name] = best_params
    print(f'best parameters: {best_params}')

    # Retrain the best model with the whole training set
    best_model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = best_model.predict(X_test)
    
    # Calculate the probabilities (not for SVM as this is not possible)
    if classifier != 'SVM':
        y_pred_proba = best_model.predict_proba(X_test)
        
        # Find the highest probability for each observation
        highest_prob = np.amax(y_pred_proba, axis = 1)
    
        # Create a DataFrame with test observations, highest probabilities, and predicted classes
        predictions_df = pd.DataFrame({'Observation_nr': y_test.index, 'Probability': highest_prob, 'Prediction': y_pred})
        
    else:
        # Create a DataFrame with test observations and predicted classes
        predictions_df = pd.DataFrame({'Observation_nr': y_test.index, 'Prediction': y_pred})
        
    # Store the final predictions with its probability for the test set
    predictions_df.to_csv(f'./Output/predictions/{name}.csv', index = False, header = True)
    #predictions_df.to_excel(f'./Output/predictions/{name}.xlsx', index = False, header = True)

    # Calculate the classification metrics
    accuracy, precision, recall, f1 = get_classification_metrics(y_test, y_pred)
    
    # print the results
    print(f'Results for {name}:')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1: {f1}')
    
    # add the results to the dataframe with all the results
    results_all_df.loc[name] = [vectorizer, FS, classifier, resampling, accuracy, precision, recall, f1]

# %%
# 5. Define a function to transform the data into embeddings based on a trained model
def vectorize_embedding(headline, model, size):
    
    # Split the headline into individual words
    words = headline.split()

    # Retrieve word vectors for each word in the headline
    words_vecs = [model.wv[word] for word in words if word in model.wv]

    # If no word vectors are found (i.e., no matching words in the pretrained model),
    # return a zero vector of the defined dimension
    if len(words_vecs) == 0:
        return np.zeros(size)

    # Convert the list of word vectors into a numpy array and average across all words
    words_vecs = np.array(words_vecs)
    mean_vector = words_vecs.mean(axis=0)

    return mean_vector

# %%
# 6. Define a function to transform the data into embeddings based on a pretrained model
def vectorize_pretrained(headline, pre_trained_model, size):

    # Split the headline into individual words
    words = headline.split()

    # Retrieve word embedding for each word in the headline
    words_vecs = [pre_trained_model[word] for word in words if word in pre_trained_model]

    # If no word vectors are found (i.e., no matching words in the pretrained model),
    # return a zero vector of the specified dimension
    if len(words_vecs) == 0:
        return np.zeros(size)

    # Convert the list of word vectors into a numpy array and average across word vectors
    words_vecs = np.array(words_vecs)
    mean_vector = words_vecs.mean(axis=0)

    return mean_vector

# %%
# define the independent and dependent variables
X_train = df_train['cleaned_headline']
X_test = df_test['cleaned_headline']

y_train = df_train['category']
y_test = df_test['category']

# %% [markdown]
# # 2. Embeddings

# %% [markdown]
# In this notebook, I used the same base classifiers and resampling techniques as in the previous notebook 'B. Vectorization'. Moreover, I also initialize the models the first time they are used (section 2.1). Further, I again hypertune the parameters of each model trough cross validation with GridSearchCV. Moroever, I used the same hypertuned the parameters using the same values as in the previous notebook.
#
# Further, I also used the same resampling strategies as in the previous notebook.

# %% [markdown]
# ## 2.1 Word2Vec

# %% [markdown]
# The first embedding model that I used to transfrom my textual data into numerical vectors. Word2Vec is a neural network-based technique designed by Google to learn vector embeddings. Besides, it has two different ways of learning its context, which will both be implemented in this notebook:
#
# 1. CBOW = Continuous bag of words. This model trains each word against its context. In other words, what words are likely to appear near a given word.
# 2. Skipgram = This model trains each context against the word. Here, the context is given and the algorithm searches for the word that is likely to appear.

# %%
# Define with what vectorizer we build the models with for storage
vectorizer = 'Word2Vec'

# %% [markdown]
# ## 2.1 Create word embeddings with CBOW

# %%
# Define the implementation method of word2vec
FS = 'cbow'

# %%
# Create an array of seperate words for each headline as input for the model
headlines_train = [headline.split() for headline in X_train]

# %%
# Define the dimension of the vector
size = 300

# define the cbow_model and train on training set headlines
cbow_model = Word2Vec(headlines_train, 
                 min_count = 2,          # Ignore words that appear less than this
                 vector_size = size,      # Dimensionality of word embeddings
                 workers = 8,            # Number of processors (parallelisation)
                 window = 5,             # Context window for words during training
                 epochs = 50,            # Number of epochs training over corpus
                 sg = 0)                 # 0 for CBOW and 1 for skipgram

# %%
# Transform the independent variable of the train and the test set
X_train_cbow = np.array([vectorize_embedding(headline, cbow_model, size) for headline in X_train])
X_test_cbow = np.array([vectorize_embedding(headline, cbow_model, size) for headline in X_test])

# %% [markdown]
# ### 2.1.1 Without resampling

# %%
# Define the resampling technique
resampling = 'None'

# %% [markdown]
# #### A. Logistic regression

# %%
# define the model characteristics
model_name = 'cbow_log_w'
classifier = 'logR'

# Initialize the classifier
logreg = LogisticRegression(random_state = 7)

# Define the parameter grid
param_grid_log = {
    'penalty': ['None','l1', 'l2'], # normal, lasso or ridge
    'C': [0.1, 1, 10]               # The inverse penalization term (smaller is higher penalization)
}

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_cbow, X_test_cbow, y_train, y_test,
                   vectorizer, FS, classifier, resampling)
# Out:
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 30 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'elasticnet', 'l1', 'l2', 'none' (deprecated)} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.37789147        nan        nan 0.40557216
#         nan        nan 0.40897857]
#   warnings.warn(
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# best parameters: {'C': 10, 'penalty': 'l2'}
# /Users/Artur/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Results for cbow_log_w:
# Accuracy: 0.9148936170212766
# Precision: 0.490976349981819
# Recall: 0.341393754696866
# F1: 0.39620140524709746

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'cbow_DT_w'
classifier = 'DT'

# Initialize the classifier
tree = DecisionTreeClassifier(random_state = 7)

# Define the parameter grid
param_grid_DT = {
    'criterion': ['gini'],          # Define the splitting criteria: Gini index for node impurity
    'min_samples_leaf': [1, 2],     # Define the minimum number of samples required to be at leaf node
    'max_features': [None, 'sqrt']  # Define the number of features to consider when looking for the best split
}

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_cbow, X_test_cbow, y_train, y_test,
                   vectorizer, FS, classifier, resampling)
# Out:
# best parameters: {'criterion': 'gini', 'max_features': None, 'min_samples_leaf': 1}
# Results for cbow_DT_w:
# Accuracy: 0.8632328463103385
# Precision: 0.22000515730664244
# Recall: 0.2291982476151896
# F1: 0.22370150639969272

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'cbow_svm_w'
classifier = 'SVM'

# Initialize the classifier
svm = SVC(random_state = 7)

# Define the parameter grid
param_grid_svm = {
    'C': [0.1, 1, 10, 100], # inverse regularization parameter
    'kernel': ['linear', 'poly', 'rbf'], # what type of kernel need to be used (rbf = radial kernel)
}

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_cbow, X_test_cbow, y_train, y_test,
                   vectorizer, FS, classifier, resampling)
# Out:
# best parameters: {'C': 100, 'kernel': 'rbf'}
# Results for cbow_svm_w:
# Accuracy: 0.9107638246717218
# Precision: 0.4642520570714127
# Recall: 0.34885371463321097
# F1: 0.3932336178387882

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'cbow_rf_w'
classifier = 'RF'

# Initialize the classifier
rfc = RandomForestClassifier(random_state = 7, n_jobs = -1)

# Define the parameter grid
param_grid_rf = {
    'criterion': ['gini'],          # Define the splitting criteria: Gini index for node impurity
    'n_estimators': [100, 500],     # the number of trees to use when building the model
    'min_samples_leaf': [1, 2],     # Define the minimum number of samples required to be at leaf node
    'max_features': [None, 'sqrt']  # Define the number of features to consider when looking for the best split
}

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_cbow, X_test_cbow, y_train, y_test,
                   vectorizer, FS, classifier, resampling)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-c9fd8dd194c1> in <module>
#       1 # perform a grid search for the logistic regression model
#       2 # the results are automatically stored in results_all_df and best_params_dict
# ----> 3 perform_grid_search(model_name, rfc, param_grid_rf, X_train_cbow, X_test_cbow, y_train, y_test,
#       4                    vectorizer, FS, classifier, resampling)
#
# <ipython-input-93-597a598ecee4> in perform_grid_search(name, model, param_grid, X_train, X_test, y_train, y_test, vectorizer, FS, classifier, resampling)
#       7     # Perform the grid search using cross-validation
#       8     grid_search = GridSearchCV(model, param_grid, cv=skf, scoring=scoring)
# ----> 9     grid_search.fit(X_train, y_train)
#      10
#      11     # Get the best model and its hyperparameters
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     471             # parallel_backend contexts set at a higher level,
#     472             # since correctness does not rely on using threads.
# --> 473             trees = Parallel(
#     474                 n_jobs=self.n_jobs,
#     475                 verbose=self.verbose,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'cbow_ada_w'
classifier = 'ADA'

# Initialize decision tree base estimator for AdaBoost
base_estimator = DecisionTreeClassifier(random_state = 7)

# Initialize AdaBoost classifier
ada = AdaBoostClassifier(base_estimator = base_estimator, random_state = 7)

# Define parameter grid for AdaBoost
param_grid_ada = {
    'n_estimators': [50, 100, 250],   # the maximum number of estimators before boosting is terminated
    'learning_rate': [0.1, 0.5, 1.0], # weight applied to each classifier at boosting iteration
                                      # A higher learning rate increases the contribution of each classifier. 
}

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_cbow, X_test_cbow, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.2 With undersampling

# %%
# Define the resampling technique
resampling = 'Und'

# %%
# Define the categories and the maximum number of samples
categories = df_train["category"].unique()

# %% [markdown]
# #### First strategy

# %% [markdown]
# #Define the minimum number of samples for a class
# min_samples = min(y_train.value_counts())
#
# #Define the maximum number of samples per class to keep the ratio 1 to 4 for each class
# max_samples = min_samples*4
#
# #Create a dictionary to store the actual maximum imbalance per class
# max_imbalance = {}
#
# #Calculate the actual maximum imbalance for each class
# for category in categories:
#
#     # Check if the number of samples for the category is lower than the desired maximum
#     if (y_train.value_counts()[category]) < max_samples:
#
#         # Set the actual maximum to the number of available samples
#         max_imbalance[category] = y_train.value_counts()[category]
#
#     else:
#         # Set the actual maximum to the desired maximum
#         max_imbalance[category] = max_samples

# %% [markdown]
# #### Second strategy

# %%
# Calculate the number of samples in the biggest minority category
rus_n = df_train['category'].value_counts().sort_values(ascending=False)[1]

# Dictionary to store the actual maximum imbalance per class for undersampling
max_imbalance_u = {}

# Calculate the actual maximum imbalance for each class
for category in categories:
    if category == 'None':
        max_imbalance_u[category] = rus_n
    else:
        # Set the actual maximum to the number of available samples
        max_imbalance_u[category] = y_train.value_counts()[category]

# %%
# Create the random undersampler with maximum imbalance
undersampler = RandomUnderSampler(sampling_strategy = max_imbalance_u, random_state = 7)

# Undersample the data
X_train_cbow_und, y_train_cbow_und = undersampler.fit_resample(X_train_cbow, y_train)
#y_train_cbow_und.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'cbow_log_u'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_cbow_und, X_test_cbow, y_train_cbow_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'cbow_DT_u'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_cbow_und, X_test_cbow, y_train_cbow_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'cbow_svm_u'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_cbow_und, X_test_cbow, y_train_cbow_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'cbow_rf_u'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_cbow_und, X_test_cbow, y_train_cbow_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'cbow_ada_u'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_cbow_und, X_test_cbow, y_train_cbow_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.3 With oversampling

# %%
# Define the resampling technique
resampling = 'Ove'

# %%
# Calculate the number of samples in the majority class
ove_n = df_train['category'].value_counts().sort_values(ascending=False)[0]

# Oversample until the number of observations equals a fourth of the majority class
max_samples = int(ove_n/4)

# Dictionary to store the actual maximum imbalance per class for oversampling
max_imbalance_o = {}

# Calculate the actual maximum imbalance for each class
for category in categories:
    if category == 'None':
        max_imbalance_o[category] = y_train.value_counts()[category]
    else:
        # Set the actual maximum to the number of available samples
        max_imbalance_o[category] = max_samples

# %%
# Create the SMOTE oversampler
oversampler = SMOTE(sampling_strategy=max_imbalance_o, random_state=7)

# Undersample the data
X_train_cbow_ove, y_train_cbow_ove = oversampler.fit_resample(X_train_cbow, y_train)
y_train_cbow_ove.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'cbow_log_o'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_cbow_ove, X_test_cbow, y_train_cbow_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'cbow_DT_o'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_cbow_ove, X_test_cbow, y_train_cbow_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'cbow_svm_o'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_cbow_ove, X_test_cbow, y_train_cbow_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'cbow_rf_o'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_cbow_ove, X_test_cbow, y_train_cbow_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'cbow_ada_o'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_cbow_ove, X_test_cbow, y_train_cbow_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ## 2.2 Create word embeddings with Skipgram

# %%
# Define the implementation method of word2vec
FS = 'skip'

# %%
# Define the dimension of the vector
size = 300

# define the cbow_model and train on training set headlines
skip_model = Word2Vec(headlines_train, 
                 min_count = 2,          # Ignore words that appear less than this
                 vector_size = size,      # Dimensionality of word embeddings
                 workers = 8,            # Number of processors (parallelisation)
                 window = 5,             # Context window for words during training
                 epochs = 20,            # Number of epochs training over corpus
                 sg = 1)                 # 0 for CBOW and 1 for skipgram

# %%
# Transform the independent variable of the train and the test set
X_train_skip = np.array([vectorize_embedding(headline, skip_model, size) for headline in X_train])
X_test_skip = np.array([vectorize_embedding(headline, skip_model, size) for headline in X_test])

# %% [markdown]
# ### 2.2.1 Without resampling

# %%
# Define the resampling technique
resampling = 'None'

# %% [markdown]
# #### A. Logistic regression

# %%
# define the model characteristics
model_name = 'skip_log_w'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_skip, X_test_skip, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'skip_DT_w'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_skip, X_test_skip, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'skip_svm_w'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_skip, X_test_skip, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'skip_rf_w'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_skip, X_test_skip, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'skip_ada_w'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_skip, X_test_skip, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.2 With undersampling

# %%
# Define the resampling technique
resampling = 'Und'

# %% [markdown]
# #### Second strategy

# %%
# Create the random undersampler with maximum imbalance
undersampler = RandomUnderSampler(sampling_strategy = max_imbalance_u, random_state = 7)

# Undersample the data
X_train_skip_und, y_train_skip_und = undersampler.fit_resample(X_train_skip, y_train)
#y_train_cbow_und.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'skip_log_u'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_skip_und, X_test_skip, y_train_skip_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'skip_DT_u'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_skip_und, X_test_skip, y_train_skip_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'skip_svm_u'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_skip_und, X_test_skip, y_train_skip_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'skip_rf_u'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_skip_und, X_test_skip, y_train_skip_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'skip_ada_u'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_skip_und, X_test_skip, y_train_skip_und, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.3 With oversampling

# %%
# Define the resampling technique
resampling = 'Ove'

# %%
# Create the SMOTE oversampler
oversampler = SMOTE(sampling_strategy=max_imbalance_o, random_state=7)

# Undersample the data
X_train_skip_ove, y_train_skip_ove = oversampler.fit_resample(X_train_skip, y_train)
#y_train_skip_ove.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'skip_log_o'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_skip_ove, X_test_skip, y_train_skip_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'skip_DT_o'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_skip_ove, X_test_skip, y_train_skip_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'skip_svm_o'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_skip_ove, X_test_skip, y_train_skip_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'skip_rf_o'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_skip_ove, X_test_skip, y_train_skip_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'skip_ada_o'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_skip_ove, X_test_skip, y_train_skip_ove, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ## 3. Pretrained embeddings

# %%
# define vectorizer method
vectorizer = 'pretrained'

# %% [markdown]
# ### 3.1 Google news embeddings

# %%
# define type of pretrained embedding model
FS = 'google news'

# %% [markdown]
# Uses continious skipgram: http://vectors.nlpl.eu/repository/?ref=blog.paperspace.com
#
# https://www.analyticsvidhya.com/blog/2020/03/pretrained-word-embeddings-nlp/

# %%
# if downloaded offline
google_news = KeyedVectors.load_word2vec_format('/Users/Artur/Desktop/thesis_HIR_versie5/big files/google/GoogleNews-vectors-negative300.bin', binary=True)

# %%
# Download the "word2vec-google-news-300" embeddings if not downloaded ofline
#google_news = gensim.downloader.load('word2vec-google-news-300')

# %% [markdown]
# Vectorizes a headline using a pre-trained word embedding model.
#
#     Args:
#         headline (str): The input headline to be vectorized.
#         pre_trained_model (KeyedVectors): The pre-trained word embedding model.
#         size (int): The size of the resulting word vectors.
#
#     Returns:
#         np.ndarray: The vectorized representation of the headline.

# %%
def vectorize_pretrained(headline, pre_trained_model, size):

    # Split the headline into individual words
    words = headline.split()

    # Retrieve word embedding for each word in the headline
    words_vecs = [pre_trained_model[word] for word in words if word in pre_trained_model]

    # If no word vectors are found (i.e., no matching words in the pretrained model),
    # return a zero vector of the specified dimension
    if len(words_vecs) == 0:
        return np.zeros(size)

    # Convert the list of word vectors into a numpy array and average across word vectors
    words_vecs = np.array(words_vecs)
    mean_vector = words_vecs.mean(axis=0)

    return mean_vector

# %%
# Create embeddings of the train and test set based on the pretrained google_news model
X_train_google_news = np.vstack([vectorize_pretrained(headline, google_news, 300) for headline in X_train])
X_test_google_news = np.vstack([vectorize_pretrained(headline, google_news, 300) for headline in X_test])

# %% [markdown]
# ### 3.1.1 Without resampling

# %%
# Define the resampling technique
resampling = 'None'

# %% [markdown]
# #### A. Logistic regression

# %%
# define the model characteristics
model_name = 'google_log_w'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_google_news, X_test_google_news, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'google_DT_w'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_google_news, X_test_google_news, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'google_svm_w'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_google_news, X_test_google_news, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'google_rf_w'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_google_news, X_test_google_news, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'google_ada_w'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_google_news, X_test_google_news, y_train, y_test,
                   vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.2 With undersampling

# %%
# Define the resampling technique
resampling = 'Und'

# %% [markdown]
# #### Second strategy

# %%
# Create the random undersampler with maximum imbalance
undersampler = RandomUnderSampler(sampling_strategy = max_imbalance_u, random_state = 7)

# Undersample the data
X_train_google_news_und, y_train_google_news_und = undersampler.fit_resample(X_train_google_news, y_train)
#y_train_cbow_und.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'google_log_u'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_google_news_und, X_test_google_news,
                    y_train_google_news_und, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'google_DT_u'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_google_news_und, X_test_google_news,
                    y_train_google_news_und, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'google_svm_u'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_google_news_und, X_test_google_news,
                    y_train_google_news_und, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'google_rf_u'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_google_news_und, X_test_google_news,
                    y_train_google_news_und, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'google_ada_u'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_google_news_und, X_test_google_news,
                    y_train_google_news_und, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# ### 2.1.3 With oversampling

# %%
# Define the resampling technique
resampling = 'Ove'

# %%
# Create the SMOTE oversampler
oversampler = SMOTE(sampling_strategy=max_imbalance_o, random_state=7)

# Undersample the data
X_train_google_news_ove, y_train_google_news_ove = oversampler.fit_resample(X_train_google_news, y_train)
#y_train_skip_ove.value_counts()

# %% [markdown]
# #### A. Logistic Regression

# %%
# define the model characteristics
model_name = 'google_log_o'
classifier = 'logR'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_google_news_ove, X_test_google_news,
                    y_train_google_news_ove, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### B. Decision Tree

# %%
# define the model characteristics
model_name = 'google_DT_o'
classifier = 'DT'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, tree, param_grid_DT, X_train_google_news_ove, X_test_google_news,
                    y_train_google_news_ove, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### C. Support Vector Machine

# %%
# define the model characteristics
model_name = 'google_svm_o'
classifier = 'SVM'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, svm, param_grid_svm, X_train_google_news_ove, X_test_google_news,
                    y_train_google_news_ove, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### D. Random Forest Classifier

# %%
# define the model characteristics
model_name = 'google_rf_o'
classifier = 'RF'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, rfc, param_grid_rf, X_train_google_news_ove, X_test_google_news,
                    y_train_google_news_ove, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# #### E. Adaboost classifier

# %%
# define the model characteristics
model_name = 'google_ada_o'
classifier = 'ADA'

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, ada, param_grid_ada, X_train_google_news_ove, X_test_google_news,
                    y_train_google_news_ove, y_test, vectorizer, FS, classifier, resampling)

# %% [markdown]
# ## 4. Glove embeddings

# %%
# Download the "glove-twitter-25" embeddings
glove_twitter_100 = gensim.downloader.load('glove-twitter-100')
# Out:
# [==================================================] 100.0% 199.5/199.5MB downloaded

# %%
X_train_glove = np.vstack([vectorize_pretrained(headline, glove_twitter_100, 100) for headline in X_train])
X_test_glove = np.vstack([vectorize_pretrained(headline, glove_twitter_100, 100) for headline in X_test])

# %%
# perform a grid search for the logistic regression model
# the results are automatically stored in results_all_df and best_params_dict
perform_grid_search(model_name, logreg, param_grid_log, X_train_glove, X_test_glove, y_train, y_test,
                   vectorizer, FS, classifier, resampling)
# Out:
# best parameters: {'C': 10, 'penalty': 'l2'}
# Results for cbow_log_w:
# Accuracy: 0.9040133160717588
# Precision: 0.404330300307501
# Recall: 0.18227815053730115
# F1: 0.2288104955249781

# %%
# load the whole embedding into memory
embeddings_index = dict()
f = open('/Users/Artur/Desktop/thesis_HIR_versie5/big files/glove_6B/glove.6B.300d.txt')

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs

f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
headlines
# Out:
# [['head',
#   'u',
#   'patent',
#   'granted',
#   'se',
#   'delaware',
#   'may',
#   'titled',
#   'composition',
#   'comprising',
#   'acrylic',
#   'block',
#   'copolymer',
#   'uvcurable',
#   'copolymer',
#   'method',
#   'making',
#   'using'],
#  ['societe',
#   'generale',
#   'launch',
#   'nextgeneration',
#   'card',
#   'integrating',
#   'dynamic',
#   'security',
#   'code'],
#  ['plc', 'form', 'communication'],
#  ['4q', 'earnings', 'snapshot'],
#  ['form', 'investment', 'manager', 'group', 'plc'],
#  ['plc', 'transaction', 'share'],
#  ['northern', 'form', 'group', 'plc'],
#  ['plc', 'annual', 'report'],
#  ['technology',
#   'ag',
#   'delaware',
#   'applies',
#   'u',
#   'patent',
#   'titled',
#   'current',
#   'sensor',
#   'system',
#   'method',
#   'sensing',
#   'current',
#   'conductor'],
#  ['plc', 'holding', 'company'],
#  ['bank', 'set', '10th', 'coupon', 'rate', 'series', 'bo21', 'bond'],
#  ['wipo',
#   'publishes',
#   'patent',
#   '2substituted',
#   '5phenyl12dihydro3h3benzazepine3carboxamide',
#   'derivative',
#   'brd4',
#   'inhibitor',
#   'treatment',
#   'cancer',
#   'german',
#   'inventor'],
#  ['dixons', 'plc', 'covid19', 'trading', 'update'],
#  ['u',
#   'patent',
#   'issued',
#   'siemens',
#   'nov',
#   'method',
#   'apparatus',
#   'making',
#   'distinction',
#   'magnetic',
#   'resonance',
#   'imaging',
#   'waterfat',
#   'image',
#   'chinese',
#   'inventor'],
#  ['bank',
#   'group',
#   'plc',
#   'chief',
#   'executive',
#   'retail',
#   'decided',
#   'leave',
#   'bank'],
#  ['iqvias',
#   'orchestrated',
#   'customer',
#   'engagement',
#   'selected',
#   'international',
#   'operation'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'stiffening',
#   'element',
#   'runout',
#   'swedish',
#   'inventor'],
#  ['abengoas',
#   'beni',
#   'mathar',
#   'hybrid',
#   'solargas',
#   'plant',
#   'awarded',
#   'african',
#   'development',
#   'bank'],
#  ['global',
#   'mct',
#   'oil',
#   'market',
#   'leading',
#   'player',
#   'international',
#   'ioi',
#   'klk',
#   'oleo',
#   'oleon',
#   'stepan'],
#  ['washington',
#   'use',
#   'ngridbruins',
#   'win',
#   'playoff',
#   'ticket',
#   'boston',
#   'bruin',
#   'national'],
#  ['international',
#   'patent',
#   'france',
#   'liu',
#   'david',
#   'shenren',
#   'file',
#   'application',
#   '3d',
#   'printing',
#   'internally',
#   'transparent',
#   'article'],
#  ['analyst',
#   'action',
#   'credit',
#   'lift',
#   'price',
#   'target',
#   'sprout',
#   'farmer',
#   'maintains',
#   'neutral'],
#  ['build',
#   'new',
#   'production',
#   'plant',
#   'highperformance',
#   'plastic',
#   'krefelduerdingen',
#   'germany'],
#  ['director', 'dealing', 'senior', 'executive', 'reinvest', 'dividend'],
#  ['mail', 'general', 'plc', 'half', 'year'],
#  ['plc', 'gln', 'transaction', 'share', 'july', 'updated'],
#  ['remote',
#   'management',
#   'market',
#   'strategic',
#   'assessment',
#   'ptc',
#   'inc',
#   'rockwell',
#   'automation',
#   'robert',
#   'bosch'],
#  ['new', 'giant', 'want', 'merge', 'renaultnew', 'giant', 'want', 'merge'],
#  ['acquires', 'italy', 'leading', 'social', 'agency', 'ambito5'],
#  ['profile',
#   'director',
#   'jesper',
#   'brandgaard',
#   'executive',
#   'vice',
#   'president',
#   'chief',
#   'officer',
#   'cfo',
#   'limited'],
#  ['form', 'plc', 'updated', 'april'],
#  ['comprehensive',
#   'review',
#   'potassium',
#   'acetate',
#   'market',
#   'developmentniacet'],
#  ['royal', 'report', 'buyback', 'share', 'gbp240000', 'per', 'share'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'aircraft',
#   'retention',
#   'device',
#   'cooling',
#   'tube',
#   'turbomachine',
#   'case',
#   'french',
#   'inventor'],
#  ['smith', 'plc', 'preliminary', 'result'],
#  ['san',
#   'antonios',
#   'rebecca',
#   'creek',
#   'distillery',
#   'appoints',
#   'former',
#   'exec',
#   'howard',
#   'jeffery',
#   'leadership',
#   'team'],
#  ['irish',
#   'patent',
#   'granted',
#   'deutsche',
#   'telekom',
#   'ag',
#   'titled',
#   'method',
#   'providing',
#   'enhanced',
#   'andor',
#   'efficient',
#   'hybrid',
#   'access',
#   'functionality',
#   'within',
#   'network',
#   'base',
#   'station',
#   'entity',
#   'hybrid',
#   'access',
#   'aggregation',
#   'point',
#   'node',
#   'system',
#   'providing',
#   'enhanced',
#   'andor',
#   'efficient',
#   'hybrid',
#   'access',
#   'functionality',
#   'within',
#   'network',
#   'program',
#   'computer',
#   'program',
#   'product'],
#  ['itm',
#   'kgaa',
#   'sign',
#   'research',
#   'evaluation',
#   'option',
#   'agreement',
#   'develop',
#   'folate',
#   'receptor',
#   'targeted',
#   'radionuclide',
#   'therapythe',
#   'company',
#   'combine',
#   'technology',
#   'develop',
#   'novel',
#   'theranostic',
#   'radiopharmaceuticalsmerck',
#   'kgaa',
#   'supply',
#   'folate',
#   'derivative',
#   'preparation',
#   'folatebased',
#   'radiotheranosticsitm',
#   'receive',
#   'option',
#   'exclusive',
#   'license',
#   'clinical',
#   'development',
#   'commercialization',
#   'folatebased',
#   'radiotheranostics'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'technology',
#   'oy',
#   'titled',
#   'devicetodevice',
#   'based',
#   'user',
#   'equipment',
#   'network',
#   'relay'],
#  ['sari', 'baldauf', 'succeed', 'risto'],
#  ['global', 'inv', 'uk', 'brch', 'top', 'holding'],
#  ['u',
#   'military',
#   'contract',
#   'award',
#   'system',
#   'operation',
#   'ltd',
#   'win',
#   'contract',
#   'worth'],
#  ['group', 'plc', 'transaction', 'share'],
#  ['international', 'plc', 'annual', 'result'],
#  ['ag', 'ept', 'form', 'eptri', 'plc'],
#  ['plc', 'form', 'industry', 'plc'],
#  ['uspto',
#   'published',
#   'patent',
#   'application',
#   'technique',
#   'ab',
#   'titled',
#   'screw',
#   'actuated',
#   'press',
#   'unit'],
#  ['controlling', 'shareholder', 'stake', 'amid', 'board', 'change'],
#  ['u',
#   'patent',
#   'issued',
#   'solution',
#   'network',
#   'may',
#   'spatial',
#   'location',
#   'vias',
#   'printed',
#   'circuit',
#   'board',
#   'canadian',
#   'inventor'],
#  ['plc', 'form', 'arris', 'group', 'inc'],
#  ['new', 'zealand', 'gain', 'mobile', 'customer', 'q4'],
#  ['head',
#   'wipo',
#   'publishes',
#   'patent',
#   'siemens',
#   'aktiengesellschaft',
#   'titled',
#   'lifting',
#   'system',
#   'method',
#   'electrical',
#   'testing',
#   'vibration',
#   'damper',
#   'machine',
#   'assembly'],
#  ['swiss',
#   'federal',
#   'institute',
#   'intellectual',
#   'grant',
#   'trade',
#   'mark',
#   'british',
#   'american',
#   'inc'],
#  ['sa',
#   'tta',
#   'russia',
#   'yamal',
#   'lng',
#   'start',
#   'train',
#   'twelve',
#   'month',
#   'ahead',
#   'schedule',
#   'achieves',
#   'full',
#   'capacity',
#   'updated',
#   '11dec2018'],
#  ['u',
#   'patent',
#   'issued',
#   'surface',
#   'solution',
#   'pfaffikon',
#   'dec',
#   'holding',
#   'device',
#   'surface',
#   'treatment',
#   'bar',
#   'cutter',
#   'american',
#   'swiss',
#   'inventor'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'interior',
#   'system',
#   'india',
#   'pvt',
#   'ltd',
#   'titled',
#   'shock',
#   'absorber',
#   'member',
#   'vehicle',
#   'vehicle',
#   'door',
#   'panel',
#   'assembly',
#   'including',
#   'shock',
#   'absorber',
#   'member',
#   'vehicle',
#   'including',
#   'door',
#   'panel',
#   'assembly'],
#  ['first',
#   'oil',
#   'rbc',
#   'say',
#   'opec',
#   'likely',
#   'extend',
#   'oil',
#   'production',
#   'cut',
#   'three',
#   'month'],
#  ['u',
#   'patent',
#   'issued',
#   'rousset',
#   'sept',
#   'method',
#   'detecting',
#   'thinning',
#   'substrate',
#   'integrated',
#   'circuit',
#   'back',
#   'side',
#   'integrated',
#   'circuit',
#   'french',
#   'inventor'],
#  ['waterton',
#   'announces',
#   'update',
#   'slate',
#   'director',
#   'nomineesae',
#   'michael',
#   'anglin',
#   'withdraws',
#   'director',
#   'nominee',
#   'hudbay',
#   'join',
#   'board',
#   'competitor'],
#  ['sit',
#   'tight',
#   'duty',
#   'free',
#   'youthomas',
#   'deploys',
#   'manhattan',
#   'associate',
#   'taxfree',
#   'seat'],
#  ['recall', 'ram', 'pickup'],
#  ['bmo', 'gcb', 'ucits', 'etf', 'net', 'value'],
#  ['group', 'plc', 'srp', 'company', 'act', 's430', '2b', 'disclosure'],
#  ['nomura', 'international', 'plc', 'ept', 'form', 'plc'],
#  ['pharmaceutical', 'sign', 'distribution', 'agreement', 'omega'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['australian',
#   'contract',
#   'award',
#   'pty',
#   'ltd',
#   'awarded',
#   'contract',
#   'worth',
#   'labour',
#   'hire'],
#  ['london', 'notice', 'admission', 'trading'],
#  ['market', 'fall', 'gloomy'],
#  ['completes',
#   'transaction',
#   'sell',
#   'electrolyte',
#   'manufacturing',
#   'suzhou',
#   'china',
#   'shenzhen',
#   'capchem'],
#  ['morgan', 'stanley', 'capital', 'llc', 'form', 'eptri', 'sky', 'plc'],
#  ['group', 'plc', 'halfyear', 'report'],
#  ['mena',
#   'nutraceuticals',
#   'market',
#   'newtrition',
#   'general',
#   'mill',
#   'kellogg',
#   'amway',
#   'arla',
#   'food',
#   'quaker',
#   'look',
#   'expand',
#   'presence',
#   'say',
#   'future',
#   'market',
#   'insight'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'technology',
#   'ground',
#   'fault',
#   'direction',
#   'determination',
#   'medium',
#   'high',
#   'voltage',
#   'distribution',
#   'network',
#   'chinese',
#   'british',
#   'inventor'],
#  ['dgapnews', 'completes', 'acquisition', 'cyprotex', 'plc', 'english'],
#  ['elgin',
#   'compare',
#   'top',
#   'competitorschicagoarea',
#   'vw',
#   'dealership',
#   'creates',
#   'comparison',
#   'research',
#   'page',
#   'curious',
#   'suv',
#   'buyer'],
#  ['australian',
#   'patent',
#   'granted',
#   'plant',
#   'science',
#   'titled',
#   'plant',
#   'increased',
#   'yield'],
#  ['ab', 'nomination', 'committee', 'annual', 'general', 'meeting'],
#  ['vanguard', 'group', 'form', 'group', 'plc'],
#  ['plc',
#   'publication',
#   'supplement',
#   'base',
#   'prospectus',
#   'updated',
#   '30nov2018'],
#  ['empire',
#   'state',
#   'development',
#   'announces',
#   'north',
#   'america',
#   'relocate',
#   'north',
#   'america',
#   'office',
#   'new',
#   'york',
#   'city'],
#  ['italian', 'deal', 'ferrero', 'tiscali'],
#  ['plc', 'form', 'retail', 'group', 'plc'],
#  ['plc', 'update', 'court', 'hearing'],
#  ['committee', 'proposes', 'election', 'staffan', 'bohman', 'chairman'],
#  ['london', 'group', 'plc', 'transaction'],
#  ['sweden',
#   'market',
#   'outlook',
#   'update',
#   'market',
#   'trend',
#   'regulation',
#   'competitive',
#   'landscape',
#   'vattenfall',
#   'ab'],
#  ['telefonica',
#   'huawei',
#   'join',
#   'force',
#   'develop',
#   'smart',
#   'category',
#   'latin',
#   'america'],
#  ['plc', 'blocklisting', 'interim', 'review'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'nv',
#   'plc',
#   'oral',
#   'composition',
#   'adduct',
#   'clay',
#   'antibacterial',
#   'agent',
#   'indian',
#   'inventor'],
#  ['osisko',
#   'latest',
#   'analyst',
#   'action',
#   'credit',
#   'view',
#   'agnico',
#   'eagle',
#   'joined',
#   'osisko',
#   'bid'],
#  ['latest',
#   'research',
#   'nasal',
#   'drop',
#   'market',
#   'application',
#   'industry',
#   'share',
#   'end',
#   'user',
#   'top',
#   'player',
#   'teva',
#   'sandoz',
#   'ag',
#   'mylan',
#   'allergan',
#   'plc',
#   'cipla',
#   'etc',
#   'market',
#   'research',
#   'report'],
#  ['u',
#   'patent',
#   'issued',
#   'aktiebolaget',
#   'feb',
#   'sensor',
#   'british',
#   'inventor'],
#  ['standard', 'life', 'investment', 'form', 'group', 'plc'],
#  ['data',
#   'scientist',
#   'work',
#   'predictive',
#   'analysis',
#   'large',
#   'data',
#   'volume'],
#  ['limited', 'holding', 'company'],
#  ['fil', 'limited', 'form', 'gold'],
#  ['u',
#   'patent',
#   'issued',
#   'system',
#   'aug',
#   'radiation',
#   'detector',
#   'method',
#   'manufacture',
#   'radiation',
#   'detector',
#   'british',
#   'inventor'],
#  ['plc', 'form', 'matchtech', 'group', 'plc'],
#  ['insurance',
#   'group',
#   'board',
#   'recommends',
#   'bid',
#   'canadian',
#   'intact',
#   'danish'],
#  ['u',
#   'patent',
#   'issued',
#   'aug',
#   'method',
#   'secure',
#   'detach',
#   'procedure',
#   'radio',
#   'network',
#   'finnish',
#   'inventor'],
#  ['u',
#   'patent',
#   'issued',
#   'siemens',
#   'jan',
#   'hybrid',
#   'organic',
#   'photodiode',
#   'german',
#   'inventor'],
#  ['year', 'czechia'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'feb',
#   'method',
#   'apparatus',
#   'computer',
#   'program',
#   'product',
#   'sharing',
#   'network',
#   'configuration',
#   'finnish',
#   'inventor'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'koninklijke',
#   'humidification',
#   'andor',
#   'purification',
#   'inventor'],
#  ['u',
#   'patent',
#   'issued',
#   'koninklijke',
#   'jan',
#   'steam',
#   'iron',
#   'receiving',
#   'fragrance',
#   'cartridge',
#   'inventor'],
#  ['st', 'james', 'plc', 'annual', 'result'],
#  ['expects', 'full', 'year', 'nears', 'nuclear', 'acquisition'],
#  ['plc', '1st', 'quarter', 'result'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'feb',
#   'cloudbased',
#   'connectivity',
#   'information',
#   'discovery',
#   'finnish',
#   'inventor'],
#  ['trec',
#   'notification',
#   'corporate',
#   'action',
#   'tax',
#   'reclaim',
#   'oyj',
#   'ord',
#   'shs',
#   'share',
#   'isin',
#   'fi0009004824'],
#  ['plc', 'transaction', 'share'],
#  ['capacitor',
#   'global',
#   'market',
#   'trend',
#   'revenue',
#   'analysis',
#   'including',
#   'key',
#   'player',
#   'eaton',
#   'etc'],
#  ['plc', 'directorate', 'change', 'february'],
#  ['profit',
#   'rise',
#   'despite',
#   'mass',
#   'cancellationsryanair',
#   'profit',
#   'rise',
#   'despite',
#   'mass',
#   'cancellation'],
#  ['citadel', 'group', 'form', 'retail', 'group', 'plc'],
#  ['dbrs',
#   'confirms',
#   'withdraws',
#   'rating',
#   'credit',
#   'ag',
#   'liquidity',
#   'instrument',
#   'pursuant',
#   'liquidity',
#   'agreement',
#   'afl',
#   'within',
#   'gifs',
#   'capital',
#   'company',
#   'llc'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'koninklijke',
#   'automated',
#   'personnel',
#   'identification',
#   'location',
#   'automated',
#   'procedure',
#   'monitoring',
#   'inventor'],
#  ['plc', 'holding', 'company'],
#  ['u',
#   'patent',
#   'issued',
#   'siemens',
#   'jan',
#   'method',
#   'producing',
#   'video',
#   'coding',
#   'programmeproduct',
#   'german',
#   'inventor'],
#  ['oyj',
#   'applies',
#   'u',
#   'patent',
#   'titled',
#   'arrangement',
#   'method',
#   'simulating',
#   'creping',
#   'tissue',
#   'paper'],
#  ['plc', 'blocklisting', 'interim', 'review'],
#  ['morgan',
#   'stanley',
#   'co',
#   'llc',
#   'form',
#   'eptrireplacement',
#   'anheuserbusch'],
#  ['jpmorgan', 'plc', 'form', 'eptri', 'sky', 'plc', 'amendment'],
#  ['equitable',
#   'provides',
#   'longterm',
#   'protection',
#   'tip',
#   'honor',
#   'national',
#   'longterm',
#   'awareness',
#   'month'],
#  ['announces',
#   'award',
#   'sek38bn',
#   'contract',
#   'phase',
#   'west',
#   'link',
#   'consortium'],
#  ['top', 'news', 'cut', 'profit', 'guidance', 'strike', 'cost'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['group', 'plc', 'directorpdmr', 'shareholding'],
#  ['bp', 'sell', 'petrochem', 'unit', 'ineos'],
#  ['global',
#   'piezoelectric',
#   'biosensors',
#   'market',
#   'covid19',
#   'effect',
#   'analysis',
#   'likewise',
#   'industry',
#   'booming',
#   'globaly',
#   'key',
#   'player',
#   'abbott',
#   'point',
#   'acon',
#   'laboratory',
#   'lifescan',
#   'lifesensors',
#   'etc'],
#  ['unibailrodamco', 'sell', 'stake', 'nice', 'mall', 'eur', '3125m'],
#  ['result', 'fourth', 'quarter', 'full', 'year'],
#  ['partner',
#   'kgaa',
#   'darmstadt',
#   'germany',
#   'receives',
#   'fda',
#   'fast',
#   'track',
#   'designation',
#   'evofosfamide',
#   'treatment',
#   'patient',
#   'living',
#   'advanced',
#   'pancreatic',
#   'cancer'],
#  ['plc', 'transaction', 'share'],
#  ['confirmed',
#   'industry',
#   'group',
#   'leader',
#   'dow',
#   'jones',
#   'sustainability',
#   'world',
#   'europe',
#   'index'],
#  ['plan', '100m', 'expansion', 'kansa', 'manufacturing', 'facility'],
#  ['ag',
#   'delaware',
#   'applies',
#   'u',
#   'patent',
#   'titled',
#   'method',
#   'data',
#   'communication',
#   'vehicle',
#   'data',
#   'communication',
#   'device'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'method',
#   'producing',
#   'expanded',
#   'granular',
#   'material',
#   'german',
#   'french',
#   'inventor'],
#  ['notification',
#   'accordance',
#   'finnish',
#   'market',
#   'act',
#   'chapter',
#   'blackrock',
#   'investment',
#   'management',
#   'uk',
#   'limited',
#   'decreased',
#   'holding'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'heating',
#   'system',
#   'hybrid',
#   'vehicle',
#   'method',
#   'operating',
#   'heating',
#   'system',
#   'german',
#   'inventor'],
#  ['winner', 'loser', 'summary', 'gain', 'profit', 'surge'],
#  ['swiss', 'buy', 'indonesian', 'pipe', 'producer'],
#  ['hungary', 'selects', 'ingenicos', 'mpos', 'mobile', 'payment', 'solution'],
#  ['deutsche', 'bank', 'ag', 'form', 'eptri', 'sabmiller', 'plc'],
#  ['u',
#   'patent',
#   'granted',
#   'diagnostics',
#   'operation',
#   'inc',
#   'indiana',
#   'april',
#   'titled',
#   'diagnosis',
#   'therapy',
#   'prognosis',
#   'system',
#   'invoked',
#   'event',
#   'method',
#   'thereof'],
#  ['plc', 'form', 'deutsche'],
#  ['british',
#   'land',
#   'co',
#   'plc',
#   'roger',
#   'madelin',
#   'appointed',
#   'canada',
#   'water',
#   'development'],
#  ['head',
#   'wipo',
#   'publishes',
#   'patent',
#   'appliance',
#   'aktiebolag',
#   'titled',
#   'method',
#   'washing',
#   'laundry',
#   'laundry',
#   'washing',
#   'machine',
#   'laundry',
#   'washing',
#   'machine'],
#  ['london', 'notice', 'admission', 'trading'],
#  ['group', 'result', 'june'],
#  ['group',
#   'delivery',
#   'period',
#   'october',
#   'grow',
#   'five',
#   'percent',
#   'million',
#   'vehicle'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'takeshi',
#   'watanabe',
#   'takashi',
#   'ohniwa',
#   'throttle',
#   'control',
#   'device',
#   'japanese',
#   'inventor'],
#  ['introduces',
#   'advantage',
#   'max',
#   'data',
#   'center',
#   'check',
#   'small',
#   'mediumsized',
#   'data',
#   'center'],
#  ['bayer', 'supervisory', 'board', 'chairman', 'retires'],
#  ['deutsche', 'bank', 'cut', 'job', 'profitability', 'plan'],
#  ['u',
#   'patent',
#   'issued',
#   'may',
#   'analysis',
#   'radiographic',
#   'image',
#   'british',
#   'inventor'],
#  ['moneysupermarketcom', 'group', 'plc', 'holding'],
#  ['open', 'new', 'communication', 'platform', 'berlin'],
#  ['top', 'news', 'drop', 'pwc', 'name', 'kpmg', 'new', 'auditor'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['bank', 'pekao', 'sa', 'draft', 'resolution', 'ogm'],
#  ['wppmakes',
#   'strategic',
#   'investment',
#   'refinery29',
#   'incwpp',
#   'scripps',
#   'network',
#   'interactive',
#   'partner',
#   'us50',
#   'million',
#   'series',
#   'funding',
#   'round',
#   'leading',
#   'company',
#   'millennial',
#   'woman',
#   'u'],
#  ['formulation',
#   'solution',
#   'radtech',
#   'uv',
#   'eb',
#   'technology',
#   'expo',
#   'conference'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['southampton',
#   'phd',
#   'student',
#   'win',
#   'system',
#   'award',
#   'innovative',
#   'research'],
#  ['digital', 'turnabout', 'lift', 'china'],
#  ['international',
#   'patent',
#   'publ',
#   'file',
#   'application',
#   'reporting',
#   'multicast',
#   'mac',
#   'address'],
#  ['post', 'diluted', 'eps', 'sek328'],
#  ['information', 'quote', 'nv'],
#  ['plc', 'half', 'yearly', 'report'],
#  ['u',
#   'patent',
#   'issued',
#   'nov',
#   'surgical',
#   'microscope',
#   'integrated',
#   'optical',
#   'coherence',
#   'tomography',
#   'display',
#   'system',
#   'swiss',
#   'inventor'],
#  ['plc', 'transaction', 'share'],
#  ['u',
#   'patent',
#   'issued',
#   'siemens',
#   'energy',
#   'sept',
#   'converging',
#   'flow',
#   'joint',
#   'insert',
#   'system',
#   'intersection',
#   'adjacent',
#   'transition',
#   'extending',
#   'combustor',
#   'turbine',
#   'assembly',
#   'gas',
#   'turbine',
#   'engine',
#   'florida',
#   'inventor'],
#  ['research',
#   'market',
#   'automotive',
#   'hvac',
#   'system',
#   'market',
#   'america',
#   'analysis',
#   'technology',
#   'forecast',
#   'key',
#   'vendor',
#   'denso',
#   'hanon',
#   'system',
#   'mahle'],
#  ['bp', 'capital', 'market', 'plc', 'publication', 'supplprospcts'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'koninklijke',
#   'hair',
#   'clipping',
#   'device',
#   'inventor'],
#  ['delhaize', 'held', 'back', 'action', 'stop', 'shop'],
#  ['quarterly',
#   'result',
#   'upcoming',
#   'earnings',
#   'acquisition',
#   'award',
#   'research',
#   'report',
#   'netapp',
#   'nxp',
#   'cleco',
#   'con',
#   'edisoneditor',
#   'note',
#   'information',
#   'release',
#   'please',
#   'scroll',
#   'bottom'],
#  ['smith', 'plc', 'transaction', 'share'],
#  ['morphosyss',
#   'partner',
#   'provides',
#   'update',
#   'trial',
#   'gantenerumab',
#   'prodromal',
#   'alzheimers',
#   'patient'],
#  ['u',
#   'patent',
#   'issued',
#   'sept',
#   'robust',
#   'mac',
#   'aggregation',
#   'short',
#   'mac',
#   'tag',
#   'new',
#   'jersey',
#   'inventor'],
#  ['supply', 'extra', 'citadis', 'tram', 'city', 'strasbourg'],
#  ['plc', 'directorpdmr', 'shareholding'],
#  ['icbc', 'credit', 'ucit', 'etf', 'sicav', 'net', 'value'],
#  ['insurance', 'group', 'plc', 'noting', 'lord', 'chancellor', 'announcement'],
#  ['u',
#   'patent',
#   'issued',
#   'automotive',
#   'system',
#   'jan',
#   'dual',
#   'range',
#   'high',
#   'precision',
#   'pressure',
#   'sensor',
#   'michigan',
#   'inventor'],
#  ['dgapdd', 'nv', 'english'],
#  ['group', 'start', 'commercial', 'operation', 'qclng', 'train', 'australia'],
#  ['societe', 'generale', 'sa', 'form', 'retail', 'group'],
#  ['asia',
#   'economics',
#   'see',
#   'china',
#   'economic',
#   'growth',
#   'momentum',
#   'slowing',
#   'noticeably',
#   'q3'],
#  ['peapod',
#   'digital',
#   'lab',
#   'tap',
#   'deliv',
#   'help',
#   'delhaize',
#   'usa',
#   'local',
#   'expand',
#   'day',
#   'select',
#   'marketsrelationship',
#   'support',
#   'giantmartins',
#   'effort',
#   'conquering',
#   'last',
#   'mile'],
#  ['smith', 'plc', 'holding', 'company'],
#  ['telecom', 'board', 'director', 'confirms', 'patuano', 'ceo'],
#  ['mandatory', 'notification', 'trade', 'primary', 'insider'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'oyj',
#   'titled',
#   'papermaking',
#   'agent',
#   'system',
#   'method',
#   'making',
#   'papermaking',
#   'agent',
#   'system',
#   'use'],
#  ['plc', 'form', 'eptnonri'],
#  ['general', 'group', 'plc', 'directorpdmr', 'shareholding'],
#  ['resume', 'flight', 'cuba', 'uk', 'holidaymaker', 'cuban', 'diplomat'],
#  ['group', 'plc', 'holding', 'company'],
#  ['performs', 'better', 'foreseen'],
#  ['plc', 'form', 'dd', 'plc'],
#  ['north',
#   'america',
#   'tissue',
#   'engineered',
#   'skin',
#   'substitute',
#   'market',
#   'outlook',
#   'key',
#   'player',
#   'organogenesis',
#   'inc',
#   'kinetic',
#   'concept',
#   'inc',
#   'plc',
#   'smith',
#   'plc'],
#  ['launch', 'new', 'nickel', 'strategy'],
#  ['tintos',
#   'quebec',
#   'north',
#   'shore',
#   'labrador',
#   'railway',
#   'win',
#   'grand',
#   'prize',
#   'awarded',
#   'quebec',
#   'transport',
#   'association'],
#  ['plc', 'statement', 'recent', 'press', 'speculation'],
#  ['fresenius',
#   'host',
#   'healthy',
#   'lifestyle',
#   'event',
#   'celebrity',
#   'chef',
#   'aaron',
#   'mccargo',
#   'jr',
#   'across',
#   'u',
#   'national',
#   'kidney',
#   'monthevents',
#   'feature',
#   'cooking',
#   'demo',
#   'risk',
#   'assessment',
#   'advice',
#   'help',
#   'kidney',
#   'patient',
#   'eat',
#   'well',
#   'stay',
#   'active'],
#  ['albemarle',
#   'sell',
#   'chemetall',
#   'surface',
#   'treatment',
#   'business',
#   'bln',
#   'deal'],
#  ['renaults', 'new', 'brand', 'signature', 'passion', 'life'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['aberdeen', 'management', 'plc', 'director', 'declaration'],
#  ['bank', 'plc', 'half', 'yearly', 'report'],
#  ['credit', 'eur', 'ltd', 'form', 'eptnonri', 'sa'],
#  ['societe', 'generale', 'sa', 'form', 'sky', 'plc'],
#  ['appoints', 'group', 'chief', 'operating', 'officer'],
#  ['shaw', 'co', 'lp', 'form', 'sky', 'plc'],
#  ['plc', 'transaction', 'share'],
#  ['nv', 'new', 'buyback', 'program'],
#  ['holding', 'plc', 'transaction', 'share'],
#  ['alierta', 'retire', 'telefonica', 'chairman', 'year'],
#  ['management', 'ltd', 'form', 'plc'],
#  ['property', 'plc', 'appointment', 'administrator', 'share', 'suspension'],
#  ['credit', 'eur', 'ltd', 'form', 'eptriplatform', 'specialty', 'product'],
#  ['patent',
#   'office',
#   'award',
#   'patent',
#   'technology',
#   'oy',
#   'method',
#   'apparatus',
#   'detecting',
#   'mitigating',
#   'information',
#   'security',
#   'threat'],
#  ['group', 'plc', 'transaction', 'share'],
#  ['sign',
#   'usd365m',
#   'contract',
#   'complete',
#   'demolition',
#   'abatement',
#   'four',
#   'building',
#   'new',
#   'york',
#   'city'],
#  ['manitowoc',
#   'company',
#   'present',
#   'credit',
#   '8th',
#   'annual',
#   'virtual',
#   'industrials',
#   'conference',
#   'thursday',
#   'december'],
#  ['interim', 'report', 'january', 'september', '2020third', 'quarter'],
#  ['plc', 'plc', 'result', 'period', 'ended'],
#  ['plc', 'form', 'abbvie'],
#  ['plc', 'publication', 'response', 'circular'],
#  ['nomura', 'international', 'plc', 'form', 'energy', 'plc'],
#  ['u',
#   'patent',
#   'issued',
#   'aug',
#   'classification',
#   'modelling',
#   'exception',
#   'type',
#   'integration',
#   'middleware',
#   'system',
#   'german',
#   'inventor'],
#  ['u',
#   'patent',
#   'issued',
#   'july',
#   'computer',
#   'interface',
#   'including',
#   'physiologically',
#   'guided',
#   'avatar',
#   'california',
#   'inventor'],
#  ['orpeastrong',
#   'growth',
#   'halfyear',
#   'results2017',
#   'guidance',
#   'reiterated'],
#  ['citadel', 'group', 'form', 'group', 'plc'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'pressure',
#   'casting',
#   'die',
#   'german',
#   'inventor'],
#  ['plc', 'agreed', 'acquire', 'millbrook', 'proving', 'ground', 'ltd'],
#  ['eu',
#   'ohim',
#   'trademark',
#   'design',
#   'grant',
#   'trade',
#   'mark',
#   'ozora',
#   'aktiengesellschaft'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'diabetes',
#   'inc',
#   'hoffmannla',
#   'diabetes',
#   'controlling',
#   'user',
#   'access',
#   'system',
#   'german',
#   'austrian',
#   'inventor'],
#  ['plc', 'purchase', 'share'],
#  ['plc', 'form', 'royal', 'plc'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'may',
#   'short',
#   'identifier',
#   'devicetodevice',
#   'd2d',
#   'broadcast',
#   'communication',
#   'finnish',
#   'inventor'],
#  ['plc', 'form', 'eptnonri', 'quintain', 'development', 'plc'],
#  ['newsbox', 'group', 'publishes', 'market', 'outlook', 'h1', 'search'],
#  ['australian', 'patent', 'granted', 'ag', 'titled', 'ant', 'control'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['vanguard', 'group', 'form', 'plc'],
#  ['group', 'holding', 'plc', 'annual'],
#  ['healthline', 'programme', 'hit', 'screen', 'month'],
#  ['hcl', 'tech', 'completes', 'yr', 'engagement', 'co'],
#  ['analyst',
#   'action',
#   'credit',
#   'upgrade',
#   'canadian',
#   'western',
#   'bank',
#   'outperform',
#   'back',
#   'share',
#   'price',
#   'plunge',
#   'est',
#   'unchanged'],
#  ['hld', 'ltd', 'transaction', 'share'],
#  ['dassault',
#   'dartmouth',
#   'college',
#   'expands',
#   'use',
#   'solidworks',
#   'application',
#   'innovative',
#   'education'],
#  ['siemens', 'start', 'coronavirus', 'test'],
#  ['robotics', 'sign', 'collaboration', 'agreement'],
#  ['unlocks',
#   'broader',
#   'portfolio',
#   'technology',
#   'greater',
#   'growth',
#   'opportunity',
#   'customer'],
#  ['group', 'plc', 'directorpdmr', 'shareholding'],
#  ['plc', 'transaction', 'share'],
#  ['0haf', 'change', 'corporation', 'share', 'february'],
#  ['london', 'form', 'royal'],
#  ['ftse', 'drift', 'lower', 'uschina', 'trade', 'worry'],
#  ['investor', 'irsh', 'form', 'group', 'plc', 'updated', 'june'],
#  ['holding', 'plc', 'annual', 'report'],
#  ['global',
#   'small',
#   'cell',
#   '5g',
#   'network',
#   'market',
#   'register',
#   'cagr',
#   'till',
#   'increasing',
#   'adoption',
#   'iot',
#   'technology',
#   'boost',
#   'sale',
#   'opportunity',
#   'fortune',
#   'business',
#   'insightskey',
#   'company',
#   'covered',
#   'small',
#   'cell',
#   '5g',
#   'network',
#   'market',
#   'research',
#   'report',
#   'samsung',
#   'group',
#   'comba',
#   'telecom',
#   'system',
#   'holding',
#   'ltd',
#   'cisco',
#   'system',
#   'inc',
#   'fujitsu',
#   'limited',
#   'huawei',
#   'technology',
#   'co',
#   'ltd',
#   'airspan',
#   'network',
#   'inc',
#   'commscope',
#   'inc'],
#  ['dgapdd', 'industry', 'ag', 'english'],
#  ['london', 'form'],
#  ['head',
#   'u',
#   'patent',
#   'granted',
#   'technology',
#   'oy',
#   'april',
#   'titled',
#   'method',
#   'apparatus',
#   'generating',
#   'compilation',
#   'item'],
#  ['tesaro',
#   'tsro',
#   'alert',
#   'fistel',
#   'investigates',
#   'proposed',
#   'sale',
#   'tesaro',
#   'inc',
#   'plc',
#   'shareholder',
#   'getting',
#   'fair',
#   'deal'],
#  ['backbase', 'name', 'global', 'solution', 'partner', 'year'],
#  ['london', 'form', 'property', 'plc'],
#  ['loréal',
#   'usa',
#   'announces',
#   'generation',
#   'award',
#   'winnerswomen',
#   'digital',
#   'program',
#   'honor',
#   'femalefounded',
#   'technology',
#   'company',
#   'cast',
#   'beauty',
#   'maven',
#   'mikmak'],
#  ['u',
#   'patent',
#   'issued',
#   'june',
#   'polypeptide',
#   'alphaglucosidase',
#   'activity',
#   'polynucleotides',
#   'encoding',
#   'california',
#   'inventor'],
#  ['global',
#   'toddler',
#   'wear',
#   'market',
#   'key',
#   'stakeholder',
#   'carter',
#   'armani',
#   'zara',
#   'nike',
#   'balabala',
#   'gap',
#   'benetton'],
#  ['quality',
#   'monitoring',
#   'market',
#   'receive',
#   'overwhelming',
#   'hike',
#   'key',
#   'player',
#   'general',
#   'company',
#   'siemens',
#   'ag',
#   'emerson',
#   'co',
#   '3m',
#   'company',
#   'teledyne',
#   'technology',
#   'thermo',
#   'fisher',
#   'llc',
#   'horiba',
#   'honeywell'],
#  ['british', 'american', 'plc', 'directorpdmr', 'shareholding'],
#  ['swiss',
#   'profit',
#   'decline',
#   'first',
#   'half',
#   'amid',
#   'pricing',
#   'pressure'],
#  ['egerton', 'capital', 'uk', 'llp', 'form', 'london', 'group', 'plc'],
#  ['plc', 'plc', 'uk', 'dk', 'halfyearly', 'report'],
#  ['plc', 'plc', 'fourth', 'quarter'],
#  ['silan',
#   'natural',
#   'range',
#   'weichspueler',
#   'kokoswasser',
#   'mineralien',
#   'ylang',
#   'ylang',
#   'suessgras',
#   'pfingstrose',
#   'weisser',
#   'tee',
#   'variety',
#   'available'],
#  ['london', 'form', 'royal'],
#  ['u',
#   'patent',
#   'issued',
#   'research',
#   'development',
#   'oct',
#   'readout',
#   'circuitry',
#   'image',
#   'sensor',
#   'british',
#   'inventor'],
#  ['say',
#   'tagrisso',
#   'active',
#   'lung',
#   'cancer',
#   'patient',
#   'central',
#   'nervous',
#   'system',
#   'metastasis'],
#  ['strengthens',
#   'collaboration',
#   'hp',
#   'productionready',
#   '3d',
#   'printing',
#   'material',
#   'development'],
#  ['ousts', 'ceo', 'hoping', 'ghosn', 'era'],
#  ['plc', 'holding', 'company'],
#  ['societe', 'generale', 'sa', 'form', 'merlin'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'method',
#   'removing',
#   'monomer',
#   'andor',
#   'oligomers',
#   'component',
#   'formed',
#   'polymerization',
#   'german',
#   'inventor'],
#  ['u',
#   'patent',
#   'issued',
#   'june',
#   'spatial',
#   'temporal',
#   'preequalization',
#   'swedish',
#   'inventor'],
#  ['decide', 'moving', 'hq', 'month'],
#  ['host', 'q2', 'conference', 'call', 'july'],
#  ['proposed',
#   'reclassification',
#   'share',
#   'held',
#   'mayroymayroy',
#   'file',
#   'request',
#   'amf',
#   'waiver',
#   'obligation',
#   'file',
#   'public',
#   'offer'],
#  ['plant', 'cut', 'job'],
#  ['admit',
#   'breaching',
#   'australian',
#   'consumer',
#   'law',
#   'osteo',
#   'gel',
#   'marketing'],
#  ['report', 'q1', 'fy', 'performance', 'today'],
#  ['brazil', 'approves', 'transfer', 'deal', 'involving', 'karoon', 'bp'],
#  ['relay',
#   'global',
#   'procurement',
#   'market',
#   'report',
#   'feature',
#   'mitsubishi',
#   'eaton',
#   'siemens',
#   'te',
#   'connectivity',
#   'researchandmarketscom'],
#  ['deutsche', 'bank', 'ag', 'form', 'eptri', 'sabmiller', 'plc'],
#  ['head',
#   'patent',
#   'office',
#   'granted',
#   'patent',
#   'koninkl',
#   'nv',
#   'nl',
#   'titled',
#   'caregiver',
#   'centric',
#   'acuity',
#   'adapting',
#   'multipatient',
#   'system'],
#  ['plc', 'full', 'year', 'result'],
#  ['aim', 'strong', 'growth', 'outside', 'europe'],
#  ['eu',
#   'contract',
#   'award',
#   'oslo',
#   'varme',
#   'win',
#   'eu',
#   'contract',
#   'worth',
#   'nok'],
#  ['telecom', 'sale', 'eur', 'mln', 'q1'],
#  ['societe', 'generale', 'sa', 'form', 'sky', 'plc'],
#  ['sign', 'strategic', 'partnership'],
#  ['national', 'plc', 'director', 'responsibility'],
#  ['wirecards',
#   'payment',
#   'solution',
#   'available',
#   'across',
#   'online',
#   'ikea',
#   'store',
#   'malaysia'],
#  ['group', 'plc', 'holding', 'company'],
#  ['world',
#   'sulfuric',
#   'acid',
#   'market',
#   'analysis',
#   'segment',
#   'forecast',
#   'key',
#   'player',
#   'mosaic',
#   'chemtrade',
#   'refinery',
#   'dupont',
#   'akzonobel',
#   'pvs',
#   'chemical',
#   'solution',
#   'valero',
#   'energy'],
#  ['analyst',
#   'action',
#   'credit',
#   'maintains',
#   'neutral',
#   'rating',
#   'capstone',
#   'mining',
#   'kutcho',
#   'project',
#   'sale'],
#  ['ewaste', 'market', 'thing', 'major', 'giant', 'electronic', 'recyclers'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'method',
#   'authenticating',
#   'finger',
#   'user',
#   'electronic',
#   'device',
#   'swedish',
#   'inventor'],
#  ['transgene', 'begin', 'construction', 'lyon', 'manufacturing', 'facility'],
#  ['suntrust', 'present', 'deutsche', 'bank', 'global', 'conference'],
#  ['u',
#   'patent',
#   'granted',
#   'technology',
#   'ag',
#   'delaware',
#   'january',
#   'titled',
#   'magnetic',
#   'sensor',
#   'system',
#   'method'],
#  ['cocacola',
#   'ag',
#   'notification',
#   'transaction',
#   'person',
#   'discharging',
#   'managerial',
#   'responsibility',
#   'pdmrs'],
#  ['bank', 'plc', 'form', 'eptri', 'deutsche', 'ag'],
#  ['shareholder', 'approve', 'demerger', 'listing', 'mg'],
#  ['plc', 'transaction', 'share'],
#  ['glg', 'lp', 'form', 'plc'],
#  ['change', 'corporation', 'holding', 'treasury', 'share'],
#  ['system',
#   'information',
#   'electronic',
#   'system',
#   'integration',
#   'file',
#   'patent',
#   'application',
#   'data',
#   'adaptive',
#   'analog',
#   'digital',
#   'converter'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'coating',
#   'aqueous',
#   'dispersion',
#   'containing',
#   'multistage',
#   'produced',
#   'polymer',
#   'coating',
#   'agent',
#   'composition',
#   'containing',
#   'german',
#   'inventor'],
#  ['eu',
#   'ohim',
#   'trademark',
#   'design',
#   'grant',
#   'trade',
#   'mark',
#   'iceland',
#   'meet',
#   'mint',
#   'british',
#   'american',
#   'inc'],
#  ['kairos', 'investment', 'management', 'ltd', 'form', 'holding', 'group'],
#  ['uspto', 'issue', 'trademark', 'fieldglass'],
#  ['plc', 'interim', 'result'],
#  ['plc', 'form', 'sabmiller', 'plc'],
#  ['plc', 'interim', 'result'],
#  ['lastvagnar',
#   'ab',
#   'file',
#   'patent',
#   'application',
#   'method',
#   'selecting',
#   'starting',
#   'gear'],
#  ['set', 'open', 'new', 'base', 'vilnius', 'fall'],
#  ['u',
#   'patent',
#   'granted',
#   'technology',
#   'ag',
#   'delaware',
#   'april',
#   'titled',
#   'die',
#   'fixing',
#   'method',
#   'apparatus'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'probing',
#   'increased',
#   'capacity',
#   'reliable',
#   'lowlatency',
#   'communication',
#   'swedish',
#   'inventor'],
#  ['london', 'form', 'royal', 'group'],
#  ['societe', 'generale', 'sa', 'form'],
#  ['head',
#   'u',
#   'patent',
#   'granted',
#   'siemens',
#   'aktiengesellschaft',
#   'delaware',
#   'september',
#   'titled',
#   'method',
#   'visualizing',
#   'quality',
#   'ablation',
#   'process'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['infectious',
#   'disease',
#   'diagnostic',
#   'market',
#   'swot',
#   'analysis',
#   'future',
#   'scenario',
#   'biomrieux',
#   'sa',
#   'biorad',
#   'laboratory',
#   'danaher'],
#  ['state', 'street', 'global', 'advisor', 'form', 'plc'],
#  ['lt',
#   'governor',
#   'offer',
#   'saving',
#   'option',
#   'response',
#   'national',
#   'rate',
#   'increase'],
#  ['zain',
#   'saudi',
#   'arabia',
#   'collaborate',
#   'unlock',
#   'potential',
#   'local',
#   'talent',
#   'cloud',
#   'edge',
#   'computing',
#   'digital',
#   'transformation',
#   'era'],
#  ['fil', 'limited', 'form', 'anheuserbusch', 'nv'],
#  ['finalizes',
#   'repurchase',
#   'share',
#   'cover',
#   'existing',
#   'option',
#   'plan',
#   'dividend'],
#  ['excellent',
#   'growth',
#   'high',
#   'frequency',
#   'oscillating',
#   'screen',
#   'market',
#   'comprehensive',
#   'study',
#   'key',
#   'player',
#   'group',
#   'aury',
#   'astec',
#   'industry',
#   'etc'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['patent',
#   'office',
#   'granted',
#   'patent',
#   'fr',
#   'titled',
#   'method',
#   'operating',
#   'base',
#   'station',
#   'heterogeneous',
#   'radio',
#   'access',
#   'network',
#   'base',
#   'station',
#   'thereof',
#   'method',
#   'operating'],
#  ['smash', 'record', 'aircraft', 'order'],
#  ['china', 'telecom', 'display', 'fddtdd', 'carrier', 'aggregation'],
#  ['irish',
#   'patent',
#   'granted',
#   'rollsroyce',
#   'plc',
#   'titled',
#   'brush',
#   'seal'],
#  ['plc',
#   'indv',
#   'federal',
#   'court',
#   'decline',
#   'immediate',
#   'issue',
#   'mandate',
#   'updated',
#   '12dec2018'],
#  ['societe', 'generale', 'sa', 'form', 'royal'],
#  ['plc', '3rd', 'quarter', 'result'],
#  ['blackrock', 'group', 'form', 'deutsche', 'ag'],
#  ['societe', 'generale', 'sa', 'form', 'royal'],
#  ['trowe', 'price', 'associate', 'form', 'royal', 'plc'],
#  ['eib', 'fortis', 'provide', 'eur', '500m', 'belgian', 'smes', 'midcaps'],
#  ['ipo',
#   'pakistan',
#   'received',
#   'application',
#   'hoffmannla',
#   'ag',
#   'switzerland',
#   'registration',
#   'patent',
#   'titled',
#   'imidazo12apyridin7amine'],
#  ['profile',
#   'bernd',
#   'osterloh',
#   'chairman',
#   'se',
#   'work',
#   'council',
#   'holding',
#   'se'],
#  ['eu',
#   'ohim',
#   'trademark',
#   'design',
#   'grant',
#   'trade',
#   'mark',
#   'ajexxto',
#   'ag'],
#  ['eqspvr',
#   'group',
#   'aktiengesellschaft',
#   'release',
#   'according',
#   'article',
#   'section'],
#  ['international', 'group', 'plc', 'halfyear', 'result'],
#  ['plc', 'halfyear', 'result', 'part'],
#  ['dean',
#   'mccrary',
#   'import',
#   'mobile',
#   'alabama',
#   'sell',
#   'audi',
#   'dealership',
#   'help',
#   'performance',
#   'brokerage',
#   'servicesnew',
#   'car',
#   'dealership',
#   'broker',
#   'george',
#   'chaconas',
#   'performance',
#   'brokerage',
#   'announces',
#   'sale',
#   'dean',
#   'mccrary',
#   'import',
#   'including',
#   'audi',
#   'mobile',
#   'alabama',
#   'dean',
#   'mccrary',
#   'roger',
#   'tovar'],
#  ['plc', 'directorpdmr', 'shareholding'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'bollhoff',
#   'verbindungstechnik',
#   'quick',
#   'fastener',
#   'method',
#   'connecting',
#   'two',
#   'component',
#   'mean',
#   'quick',
#   'fastener',
#   'production',
#   'method',
#   'therefor',
#   'german',
#   'inventor'],
#  ['deutsche', 'bank', 'proposes', 'appointment', 'deutsche', 'ceo', 'board'],
#  ['shareholder',
#   'alert',
#   'goldberg',
#   'law',
#   'pc',
#   'announces',
#   'filing',
#   'class',
#   'action',
#   'lawsuit',
#   'group',
#   'plc',
#   'advises',
#   'investor',
#   'loss',
#   'contact',
#   'firm'],
#  ['eu', 'approves', 'bskyb', 'purchase', 'sky', 'deutschland'],
#  ['telefonica', 'sa', 'issue', 'note'],
#  ['group', 'plc', 'voting', 'right', '6356x'],
#  ['morgan', 'stanley', 'form', 'eptnonri', 'plc'],
#  ['cto', 'want', 'review', 'building', 'decree'],
#  ['oil', 'plc', 'directorpdmr', 'shareholding'],
#  ['australia', 'loreal', 'owns', 'trademark', 'maybelline', 'lasting', 'fix'],
#  ['u',
#   'military',
#   'federal',
#   'contract',
#   'award',
#   'north',
#   'hollywood',
#   'inc',
#   'win',
#   'military',
#   'contract',
#   'worth'],
#  ['baillie', 'gifford', 'co', 'form', 'eat', 'plc'],
#  ['come', 'fighting', 'body', 'blow', 'cma'],
#  ['uspto',
#   'published',
#   'patent',
#   'application',
#   'siemens',
#   'aktiengesellschaft',
#   'titled',
#   'imaging',
#   'device',
#   'lenticular',
#   'image'],
#  ['plc', 'transaction', 'share'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'short',
#   'range',
#   'radar',
#   'cohabitation',
#   'swedish',
#   'inventor'],
#  ['societe', 'generale', 'sa', 'form', 'sky', 'plc'],
#  ['plc', 'directorpdmr', 'shareholding'],
#  ['securian',
#   'launch',
#   'integrated',
#   'credit',
#   'protection',
#   'claim',
#   'solution',
#   'credit',
#   'union'],
#  ['cop', 'join', 'un', 'sustainable', 'initiative'],
#  ['plc', 'form', 'eptnonri', 'flybe', 'group', 'plc'],
#  ['could', 'move', 'job'],
#  ['solar',
#   'vehicle',
#   'market',
#   'expected',
#   'reach',
#   'cagr',
#   'top',
#   'leader',
#   'ag',
#   'ford',
#   'motor',
#   'ag',
#   'zf',
#   'friedrichshafen',
#   'ag',
#   'ag',
#   'tesla',
#   'nissan'],
#  ['interteks',
#   'technology',
#   'center',
#   'laboratory',
#   'extends',
#   'iso',
#   'accreditation',
#   'environmental',
#   'water',
#   'soil',
#   'testing'],
#  ['plc', 'directorpdmr', 'shareholding'],
#  ['faureciacea', 'join', 'fuel', 'cell', 'stack', 'technology'],
#  ['plc', 'additional', 'listing'],
#  ['u', 'patent', 'issued', 'may', 'steering', 'wheel', 'german', 'inventor'],
#  ['uspto',
#   'published',
#   'patent',
#   'application',
#   'titled',
#   'bidirectional',
#   'cytosine',
#   'deaminaseencoding',
#   'selection',
#   'marker'],
#  ['australia',
#   'patent',
#   'finland',
#   'file',
#   'application',
#   'system',
#   'control',
#   'cell',
#   'electrolytic',
#   'recovery',
#   'metal'],
#  ['company', 'inc', 'report', 'annual', 'report', 'form', '10k'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'jan',
#   'fill',
#   'lighting',
#   'apparatus',
#   'california',
#   'inventor'],
#  ['uk', 'insurance', 'profile', 'plc'],
#  ['fulgent',
#   'genetics',
#   'inc',
#   'present',
#   '25thâ',
#   'annual',
#   'credit',
#   'conference',
#   'november'],
#  ['qatar',
#   'reportedly',
#   'considers',
#   'increasing',
#   'stake',
#   'deutsche',
#   'bank'],
#  ['gemany', 'group', 'face', 'stormy', 'shareholder', 'meeting'],
#  ['ag', 'included', 'dax', 'new', 'composition', 'tecdax', 'mdax', 'sdax'],
#  ['u',
#   'patent',
#   'issued',
#   'dec',
#   'method',
#   'producing',
#   'expandable',
#   'granulates',
#   'containing',
#   'polylactic',
#   'acid',
#   'german',
#   'inventor'],
#  ['plc',
#   'azn',
#   'divest',
#   'u',
#   'synagis',
#   'right',
#   'sobi',
#   'updated',
#   '13nov2018'],
#  ['u',
#   'patent',
#   'issued',
#   'orange',
#   'jan',
#   'method',
#   'navigating',
#   'sound',
#   'content',
#   'french',
#   'inventor'],
#  ['plc', 'holding', 'company'],
#  ['societe', 'generale', 'sa', 'form', 'anheuserbusch', 'sanv'],
#  ['global', 'investor', 'form', 'group', 'plc'],
#  ['change', 'channel', 'range', 'tuning', 'anvia', 'deal'],
#  ['london', 'group', 'plc', 'directorpdmr', 'shareholding'],
#  ['businesswire', 'solid', 'organic', 'growth', 'sale'],
#  ['societe', 'generale', 'sa', 'form', 'sky', 'plc'],
#  ['holding',
#   'acquires',
#   'jennewein',
#   'biotechnologie',
#   'enter',
#   'lead',
#   'highgrowth',
#   'human',
#   'milk',
#   'oligosaccharide',
#   'market'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['credit', 'sa', 'result', 'second', 'quarter', 'first', 'half'],
#  ['receives',
#   'positive',
#   'chmp',
#   'recommendation',
#   'ilarisr',
#   'treat',
#   'rare',
#   'disease',
#   'adult',
#   'child',
#   'called',
#   'periodic',
#   'fever',
#   'syndrome'],
#  ['join', 'ftse', 'drop'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'basal',
#   'titration',
#   'adaptive',
#   'target',
#   'glucose',
#   'level',
#   'danish',
#   'inventor'],
#  ['uspto',
#   'published',
#   'patent',
#   'application',
#   'koninklijke',
#   'nv',
#   'titled',
#   'light',
#   'control',
#   'system',
#   'use',
#   'within',
#   'hospital',
#   'environment'],
#  ['plc', 'ved', 'q3', 'production', 'release'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['open', 'high', 'tech', 'contract', 'design', 'hub', 'brazil'],
#  ['nanocomposites',
#   'market',
#   'report',
#   'industry',
#   'size',
#   'leading',
#   'key',
#   'company',
#   'specialty',
#   'inc',
#   'espin',
#   'technology',
#   'inc',
#   'ei',
#   'du',
#   'pont',
#   'de',
#   'nemours',
#   'company',
#   'dupont',
#   'degussa'],
#  ['comment', 'rumor', 'related', 'juniper', 'network'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'leybold',
#   'vacuum',
#   'rotor',
#   'alloy',
#   'turbo',
#   'molecular',
#   'pump',
#   'german',
#   'inventor'],
#  ['holding', 'plc', 'transaction', 'share'],
#  ['metsos', 'eps', 'decline'],
#  ['plc', 'additional', 'listing'],
#  ['cqs', 'form', 'plc'],
#  ['connected',
#   'announce',
#   'collaboration',
#   'develop',
#   'innovative',
#   'solution',
#   'better',
#   'support',
#   'people',
#   'living',
#   'epilepsy'],
#  ['received',
#   'eur',
#   'million',
#   'additional',
#   'payable',
#   'tax',
#   'finland',
#   'regarding',
#   'year',
#   '20072010the',
#   'company',
#   'make',
#   'complaint',
#   'decision'],
#  ['notice', 'annual', 'general', 'meeting'],
#  ['adtran',
#   'telefónica',
#   'showcase',
#   'open',
#   'converged',
#   '10g',
#   'mobile',
#   'world',
#   'congresstelefónica',
#   'demo',
#   'key',
#   'element',
#   'operator',
#   'global',
#   'ftth',
#   'coverage',
#   'goal',
#   'evolve',
#   'million'],
#  ['vdnrf',
#   'ceo',
#   'tom',
#   'albanese',
#   'q4',
#   'result',
#   'earnings',
#   'call',
#   'transcript'],
#  ['plc', 'form', 'energy', 'plc'],
#  ['australia',
#   'patent',
#   'ionis',
#   'pharmaceutical',
#   'file',
#   'application',
#   'glp1',
#   'receptor',
#   'ligand',
#   'moiety',
#   'conjugated',
#   'oligonucleotides',
#   'us',
#   'thereof'],
#  ['plc', 'sale', 'brokerdealer', 'network', 'u'],
#  ['plc', 'holding', 'company'],
#  ['group', 'report', 'full', 'year', 'report', 'q4'],
#  ['u',
#   'patent',
#   'issued',
#   'jan',
#   'method',
#   'module',
#   'managing',
#   'packet',
#   'defined',
#   'network',
#   'swedish',
#   'inventor'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'method',
#   'device',
#   'protecting',
#   'data',
#   'swedish',
#   'inventor'],
#  ['u',
#   'patent',
#   'issued',
#   'koninklijke',
#   'april',
#   'adaptive',
#   'circuit',
#   'german',
#   'inventor'],
#  ['group', 'plc', 'voting', 'right'],
#  ['head',
#   'u',
#   'patent',
#   'granted',
#   'siemens',
#   'aktiengesellschaft',
#   'delaware',
#   'september',
#   'titled',
#   'multiwall',
#   'gas',
#   'turbine',
#   'airfoil',
#   'cast',
#   'using',
#   'ceramic',
#   'core',
#   'formed',
#   'fugitive',
#   'insert',
#   'method',
#   'manufacturing'],
#  ['global',
#   'port',
#   'royal',
#   'sell',
#   'estonian',
#   'oil',
#   'terminal',
#   'veos',
#   'liwathon',
#   'part'],
#  ['myanmar', 'post', 'nok374mn', 'operating', 'profit', 'q215'],
#  ['france', 'change', 'name', 'gazel', 'energie'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'jan',
#   'trench',
#   'transistor',
#   'manufacturing',
#   'method',
#   'trench',
#   'transistor',
#   'austrian',
#   'german',
#   'inventor'],
#  ['societe', 'generale', 'sa', 'form', 'royal'],
#  ['invesco', 'limited', 'form', 'london', 'group', 'plc'],
#  ['plc', 'transaction', 'share'],
#  ['australia',
#   'patent',
#   'intellectual',
#   'development',
#   'astex',
#   'therapeutic',
#   'file',
#   'application',
#   'nrf2',
#   'regulator'],
#  ['know', 'undervalued', 'scenario', 'berenberg'],
#  ['insurance',
#   'stock',
#   'faring',
#   'china',
#   'life',
#   'insurance',
#   'american',
#   'equity',
#   'investment',
#   'life',
#   'torchmark'],
#  ['brilinta',
#   'approved',
#   'u',
#   'reduce',
#   'risk',
#   'stroke',
#   'patient',
#   'acute',
#   'ischemic',
#   'stroke',
#   'highrisk',
#   'transient',
#   'ischemic',
#   'attack'],
#  ['investor', 'form', 'clinigen', 'group', 'plc'],
#  ['market',
#   'chatter',
#   'said',
#   'talk',
#   'u',
#   'resolve',
#   'probe',
#   'toxic',
#   'mortgage'],
#  ['analyst', 'action', 'lg', 'display', 'co', 'upgraded', 'neutral', 'credit'],
#  ['national', 'plc', 'transaction', 'share'],
#  ['societe', 'generale', 'sa', 'form', 'takeda'],
#  ['trial', 'cloudbased', 'ran', 'architecture'],
#  ['royal', 'caribbean', 'cruise', 'ltd', 'declares', 'dividend'],
#  ['plc', 'transaction', 'share'],
#  ['regulatory',
#   'u',
#   'vice',
#   'president',
#   'address',
#   'disruption',
#   'innovation',
#   'profession',
#   'annual',
#   'american',
#   'association',
#   'law',
#   'library',
#   'conference'],
#  ['american',
#   'report',
#   'increase',
#   'q1',
#   'production',
#   'copper',
#   'equivalent',
#   'basis'],
#  ['unveils',
#   'step',
#   'cloud',
#   'powered',
#   'hana®customers',
#   'benefit',
#   'new',
#   'pricing',
#   'access',
#   'hana®',
#   'platform',
#   'hana',
#   'marketplace',
#   'simplifies',
#   'discovery',
#   'purchase',
#   'deployment'],
#  ['suny', 'orange', 'receives', 'nearly', '3m', 'title', 'grant'],
#  ['regulatory',
#   'disclosure',
#   'award',
#   'performance',
#   'review',
#   'production',
#   'report',
#   'schedule',
#   'analyst',
#   'note',
#   'jd',
#   'crheditor',
#   'note',
#   'information',
#   'release',
#   'please',
#   'scroll',
#   'bottom'],
#  ['germany', 'embattled', 'plan', 'split', 'company', 'two', 'board'],
#  ['pakistan',
#   'railway',
#   'seek',
#   'tender',
#   'supply',
#   'treadle',
#   'siemens',
#   'complete'],
#  ['deutsche', 'bank', 'ag', 'london', 'pre', 'stab', 'notice', 'kfw'],
#  ['klein',
#   'law',
#   'firm',
#   'notifies',
#   'investor',
#   'investigation',
#   'concerning',
#   'possible',
#   'violation',
#   'federal',
#   'law',
#   'credit',
#   'group',
#   'ag'],
#  ['uk',
#   'city',
#   'could',
#   'shut',
#   'amid',
#   'coronavirus',
#   'outbreak',
#   'matt',
#   'hancock'],
#  ['group', 'plc', 'group', 'plc', 'directorpdmr', 'shareholding'],
#  ['australian',
#   'contract',
#   'award',
#   'group',
#   'australia',
#   'pacific',
#   'awarded',
#   'contract',
#   'worth',
#   'glims',
#   'amtcsr',
#   'supporting',
#   'activity'],
#  ['u',
#   'patent',
#   'granted',
#   'siemens',
#   'aktiengesellschaft',
#   'delaware',
#   'may',
#   'titled',
#   'transparent',
#   'porous',
#   'siosub2coating',
#   'transparent',
#   'substrate',
#   'material',
#   'improved',
#   'optical',
#   'property'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'aktiengesellschaft',
#   'titled',
#   'selection',
#   'individual',
#   'element',
#   'display',
#   'data',
#   'eyeglass'],
#  ['change', 'executive', 'board', 'group', 'solution'],
#  ['morgan',
#   'stanley',
#   'co',
#   'form',
#   'eptri',
#   'replaces',
#   'sky',
#   'plc',
#   '7690u',
#   'public',
#   'dealing',
#   'disclosure',
#   'exempt',
#   'principal',
#   'recognised',
#   'intermediary',
#   'status',
#   'dealing',
#   'clientserving',
#   'capacity'],
#  ['defence', 'space', 'present', 'orlik', 'mpt', 'trainer'],
#  ['plc', 'publication', 'profit', 'forecast', 'final', 'dividend'],
#  ['aberdeen', 'management', 'plc', 'form', 'royal'],
#  ['u',
#   'patent',
#   'granted',
#   'ag',
# ...
#   'de',
#   'de',
#   'titled',
#   'device',
#   'comprising',
#   'socket',
#   'unit',
#   'connecting',
#   'device',
#   'providing',
#   'liquid'],
#  ['ag', 'lnnnf', 'q2', 'result', 'earnings', 'call', 'transcript'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['contract',
#   'awardceská',
#   'podnikatelská',
#   'pojistovna',
#   'insurance',
#   'group',
#   'win',
#   'contract',
#   'worth',
#   'czk'],
#  ['deal', 'snapshot', 'detection', 'close', 'acquisition', 'pathsensors'],
#  ['vanguard', 'group', 'form', 'plc'],
#  ['refutes', 'fraud', 'allegation', 'made', 'austrian', 'authority'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['london', 'group', 'plc', 'transaction'],
#  ['united',
#   'kingdom',
#   'intellectual',
#   'office',
#   'publishes',
#   'application',
#   'trademark',
#   'rare',
#   'korea',
#   'alcoholic',
#   'beverage'],
#  ['swiss',
#   'federal',
#   'institute',
#   'intellectual',
#   'granted',
#   'patent',
#   'koninklijke',
#   'nv',
#   'february',
#   'titled',
#   'converter',
#   'device',
#   'driving',
#   'solid',
#   'state',
#   'lighting',
#   'load'],
#  ['coastal', 'state', 'automotive', 'buy', 'georgia', 'u', 'dealership'],
#  ['swiss',
#   'federal',
#   'institute',
#   'intellectual',
#   'granted',
#   'patent',
#   'thermiques',
#   'february',
#   'titled',
#   'heat',
#   'exchanger',
#   'module',
#   'intended',
#   'particular',
#   'motor',
#   'vehicle'],
#  ['compagnie', 'de', 'saintgobain', 'dividend', 'declaration'],
#  ['bone',
#   'conduction',
#   'hearing',
#   'device',
#   'market',
#   'witness',
#   'steady',
#   'expansion',
#   'holding',
#   'holding',
#   'cochlear',
#   'limited',
#   'sivantors',
#   'pte',
#   'etc'],
#  ['exit',
#   'effective',
#   'following',
#   'implementation',
#   'exceptional',
#   'distribution',
#   'kind',
#   'se',
#   'share'],
#  ['launch', 'cyber', 'exposure', 'calculator'],
#  ['plc', 'holding', 'company'],
#  ['national', 'plc', 'transaction', 'share'],
#  ['annual', 'general', 'meeting', 'ab'],
#  ['siemens',
#   'provide',
#   'longterm',
#   'service',
#   'bison',
#   'energy',
#   'center',
#   'north',
#   'dakota'],
#  ['societe', 'generale', 'sa', 'form', 'plc'],
#  ['swiss',
#   'federal',
#   'institute',
#   'intellectual',
#   'granted',
#   'patent',
#   'plc',
#   'december',
#   'titled',
#   'trolley',
#   'overhead',
#   'crane'],
#  ['study',
#   'india',
#   'beer',
#   'market',
#   'budweiser',
#   'sabmiller',
#   'control',
#   'market'],
#  ['asa', 'schaschb', 'successful', 'issuance', 'unsecured', 'bond'],
#  ['plc', 'income', 'access', 'share', 'arrangement'],
#  ['bank',
#   'sell',
#   'per',
#   'cent',
#   'stake',
#   'subsidiary',
#   'aareon',
#   'advent',
#   'international',
#   'longterm',
#   'partnership',
#   'agreed',
#   'upon'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'intellectual',
#   'process',
#   'manufacturing',
#   'cermet',
#   'cemeted',
#   'carbide',
#   'component',
#   'swedish',
#   'british',
#   'inventor'],
#  ['societe', 'generale', 'sa', 'form', 'group', 'plc'],
#  ['japanese',
#   'cross',
#   'selects',
#   'partner',
#   'nucleic',
#   'acid',
#   'screening',
#   'nation',
#   'blood',
#   'supply'],
#  ['plc', 'directorate', 'change', 'updated', '08aug'],
#  ['analyst',
#   'action',
#   'jefferies',
#   'co',
#   'reiterates',
#   'company',
#   'hold',
#   'rating',
#   'lower',
#   'pt'],
#  ['state', 'street', 'global', 'advisor', 'form', 'plc'],
#  ['rollsroyce', 'holding', 'plc', 'rollsroyce', 'holding', 'plc'],
#  ['international', 'plc', 'tr1', 'notification'],
#  ['citadel', 'group', 'form', 'plc'],
#  ['telit',
#   'receives',
#   'deutsche',
#   'telekom',
#   'nbiot',
#   'certification',
#   'three',
#   'iot',
#   'module'],
#  ['plc', 'form', 'abbvie', 'inc'],
#  ['profile', 'vanessa', 'marquette', 'director', 'se'],
#  ['plc', 'transaction', 'share'],
#  ['head',
#   'patent',
#   'office',
#   'granted',
#   'patent',
#   'upm',
#   'kymmene',
#   'fi',
#   'titled',
#   'sensor',
#   'product',
#   'field',
#   'sensing'],
#  ['bank', 'rating', 'upgraded', 'moody'],
#  ['u',
#   'patent',
#   'issued',
#   'technology',
#   'aug',
#   'modulated',
#   'quasiresonant',
#   'peakcurrentmode',
#   'control',
#   'german',
#   'inventor'],
#  ['global',
#   'aluminum',
#   'pipe',
#   'sale',
#   'market',
#   'aluminum',
#   'china',
#   'billiton',
#   'constellium',
#   'nv'],
#  ['general', 'group', 'plc', 'directorpdmr', 'shareholding'],
#  ['group', 'plc', 'share', 'repurchase'],
#  ['deal',
#   'snapshot',
#   'kiewit',
#   'technology',
#   'buy',
#   'alias',
#   'consulting',
#   'business'],
#  ['launch',
#   'return',
#   'disability',
#   'etnslinked',
#   'index',
#   'developed',
#   'conjunction',
#   'return',
#   'disability',
#   'group',
#   'return',
#   'disability',
#   'etns',
#   'firstofakind',
#   'investment',
#   'product'],
#  ['ims', 'participate', 'credit', 'conference', 'conference', 'december'],
#  ['australia',
#   'international',
#   'receives',
#   'patent',
#   'novel',
#   'pharmaceutical',
#   'formulation',
#   'comprising',
#   'nsaid',
#   'cyclodextrin'],
#  ['group', 'plc', 'transaction', 'share'],
#  ['threadneedle', 'mangmt', 'hldgs', 'ltd', 'form', 'plc'],
#  ['military', 'federal', 'contract', 'awarded', 'system', 'land', 'armament'],
#  ['training',
#   'system',
#   'win',
#   'additional',
#   'million',
#   'u',
#   'army',
#   'targeting',
#   'equipment',
#   'order'],
#  ['u',
#   'patent',
#   'granted',
#   'technology',
#   'ag',
#   'delewer',
#   'june',
#   'titled',
#   'module',
#   'method',
#   'manufacturing',
#   'module'],
#  ['moscord', 'add', 'marine', 'product'],
#  ['bp', 'file', 'annual', 'report', 'form', '20f'],
#  ['plc', 'transaction', 'share'],
#  ['standard', 'life', 'investment', 'form', 'plc'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'hoffmannla',
#   'hoffmannla',
#   'bcell',
#   'cultivation',
#   'method',
#   'german',
#   'inventor'],
#  ['melqart', 'mgmt', 'form', 'plc'],
#  ['launch', 'right', 'offering'],
#  ['plc', 'transaction', 'share'],
#  ['top',
#   'news',
#   'stayathome',
#   'royal',
#   'mail',
#   'ceo',
#   'rico',
#   'back',
#   'step',
#   'suddenly'],
#  ['u',
#   'patent',
#   'issued',
#   'international',
#   'business',
#   'machine',
#   'april',
#   'managing',
#   'hydrocarbon',
#   'energy',
#   'production',
#   'proactively',
#   'maintaining',
#   'balanced',
#   'workload',
#   'brazilian',
#   'spanish',
#   'indian',
#   'american',
#   'inventor'],
#  ['plc', 'halfyear', 'report'],
#  ['deutsche', 'bank', 'cut', 'psa', 'eur', 'hold'],
#  ['vanguard', 'group', 'form', 'plc'],
#  ['uk', 'oil', 'launch', 'sale', 'pakistani', 'business'],
#  ['plc', 'form', 'eptnonri', 'plc'],
#  ['plc', 'transaction', 'share'],
#  ['societe', 'generale', 'sa', 'form', 'sa'],
#  ['smith', 'plc', 'smith', 'full', 'year', 'result'],
#  ['bank', 'launch', 'student', 'account'],
#  ['plc', 'covid19', 'dividend', 'update'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'aircraft',
#   'method',
#   'manufacturing',
#   'turbomachine',
#   'fan',
#   'reduced',
#   'noise',
#   'level',
#   'multiple',
#   'rotational',
#   'frequency',
#   'said',
#   'turbomachine',
#   'french',
#   'inventor'],
#  ['vodafonevinaphone', 'partnership', 'boost', 'revenue'],
#  ['u',
#   'patent',
#   'issued',
#   'dec',
#   'cell',
#   'selection',
#   'depending',
#   'relative',
#   'speed',
#   'terminal',
#   'access',
#   'point',
#   'swedish',
#   'inventor'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'koninklijke',
#   'filter',
#   'assembly',
#   'airway',
#   'pressure',
#   'support',
#   'system',
#   'employing',
#   'inventor'],
#  ['profit', 'warning', 'hit', 'share', 'british', 'retailer'],
#  ['analyst',
#   'action',
#   'cut',
#   'blackrock',
#   'price',
#   'target',
#   'keep',
#   'overweight',
#   'steady'],
#  ['market', 'chatter', 'selling', 'u', 'option', 'trading', 'unit', 'gts'],
#  ['chief', 'stand', 'nonexecutive', 'director'],
#  ['veterinary',
#   'animal',
#   'vaccine',
#   'market',
#   'witness',
#   'huge',
#   'growth',
#   'animal',
#   'elanco',
#   'ceva',
#   'animal'],
#  ['q2', 'performance', 'position', 'new', 'growth', 'phase'],
#  ['plc', 'energy', 'transaction', 'proceeding', 'updated', '17dec2018'],
#  ['wochenvorschau', 'termine', 'bi', 'mai'],
#  ['businesswire', 'ab', 'ibm', 'fasttrack', 'iot', 'business'],
#  ['holding', 'plc', 'voting', 'right'],
#  ['national', 'plc', 'transaction', 'share'],
#  ['morgan', 'stanley', 'capital', 'llc', 'form', 'eptri', 'sky', 'plc'],
#  ['u',
#   'patent',
#   'issued',
#   'aug',
#   'system',
#   'method',
#   'vehicle',
#   'fuel',
#   'consumption',
#   'optimization',
#   'chinese',
#   'inventor'],
#  ['wellington', 'management', 'group', 'llp', 'form', 'sa'],
#  ['france', 'ready', 'accept', '17b', 'deal', 'ge'],
#  ['slump', 'earnings', 'outlook', 'cut'],
#  ['u',
#   'patent',
#   'issued',
#   'france',
#   'april',
#   'catalyst',
#   'synthesis',
#   'methyl',
#   'mercaptan',
#   'process',
#   'producing',
#   'methyl',
#   'mercaptan',
#   'synthesis',
#   'gas',
#   'hydrogen',
#   'sulphide',
#   'french',
#   'inventor'],
#  ['plc', 'holding', 'company'],
#  ['fullyear', 'core', 'profit', 'beat', 'ceo', 'resume', 'full', 'duty'],
#  ['support', 'solidarity', 'movement', 'fire', 'notredame', 'de'],
#  ['u',
#   'patent',
#   'issued',
#   'june',
#   'method',
#   'treating',
#   'alzheimers',
#   'disease',
#   'pharmaceutical',
#   'composition',
#   'thereof',
#   'danish',
#   'inventor'],
#  ['general', 'ucits', 'etf', 'plc', 'net', 'value'],
#  ['siemens', 'profit', 'flat', 'second', 'quarter', 'affirms', 'outlook'],
#  ['plc', 'form', 'arris', 'group', 'inc', 'new'],
#  ['group',
#   'ihg',
#   'owner',
#   'association',
#   'renovation',
#   'donation',
#   'initiative',
#   'drive',
#   'impact'],
#  ['change', 'sandviks', 'group', 'executive', 'management'],
#  ['market',
#   'chatter',
#   'diagnostics',
#   'india',
#   'receives',
#   'license',
#   'test',
#   'covid19'],
#  ['u',
#   'patent',
#   'issued',
#   'siemens',
#   'industry',
#   'june',
#   'method',
#   'incorporating',
#   'individual',
#   'vehicle',
#   'data',
#   'collection',
#   'detection',
#   'recording',
#   'traffic',
#   'violation',
#   'traffic',
#   'signal',
#   'controller',
#   'texas',
#   'inventor'],
#  ['push',
#   'talk',
#   'market',
#   'hit',
#   'usd',
#   'billion',
#   'spectacular',
#   'advancement',
#   'technology',
#   'generate',
#   'vast',
#   'growth',
#   'opportunity',
#   'fortune',
#   'business',
#   'insight',
#   '¢key',
#   'company',
#   'profiled',
#   'communication',
#   'u',
#   'sonim',
#   'technology',
#   'u',
#   'ruggear',
#   'u',
#   'siyata',
#   'mobile',
#   'canada',
#   'icom',
#   'inc',
#   'japan',
#   'qualcomm',
#   'technology',
#   'inc',
#   'u',
#   'att',
#   'intellectual',
#   'u',
#   'motorola',
#   'solution',
#   'inc',
#   'u',
#   'simoco',
#   'india',
#   'sweden',
#   'ecom',
#   'instrument',
#   'u',
#   'harris',
#   'u',
#   'verizon',
#   'u',
#   'zebra',
#   'technology',
#   'u',
#   'among',
#   'others'],
#  ['profile', 'siobhan', 'moriarty', 'general', 'counsel'],
#  ['dgappublic', 'voting', 'right', 'group', 'ag', 'english'],
#  ['morgan',
#   'stanley',
#   'co',
#   'intl',
#   'plc',
#   'form',
#   'eptrireplacement',
#   'royal',
#   'plc'],
#  ['know', 'credit', 'double', 'upgrade', 'franchise', 'shift'],
#  ['donates', 'so', 'childrens', 'village', 'uk'],
#  ['bank', 'plc', 'bank', 'plc', 'form', 'eptri', 'industry', 'plc'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'azoline',
#   'compound',
#   'substituted',
#   'carbocyclic',
#   'condensed',
#   'ring',
#   'system',
#   'german',
#   'american',
#   'inventor'],
#  ['plc',
#   'file',
#   'patent',
#   'application',
#   'technique',
#   'positioning',
#   'vehicle'],
#  ['consider', 'transferring', 'vehicle', 'assembly', 'activity'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'improved',
#   'adaptive',
#   'transmit',
#   'control',
#   'sight',
#   'mimo',
#   'system',
#   'swedish',
#   'inventor'],
#  ['bp', 'plan', 'open', 'gas', 'station', 'mexico'],
#  ['u',
#   'patent',
#   'issued',
#   'loreal',
#   'sept',
#   'use',
#   'jasmonic',
#   'acid',
#   'compound',
#   'treating',
#   'greasy',
#   'skin',
#   'french',
#   'inventor'],
#  ['virtual',
#   'product',
#   'update',
#   'understanding',
#   'counterparty',
#   'exposure',
#   'using',
#   'ibor'],
#  ['analyst',
#   'action',
#   'credit',
#   'neutral',
#   'canadian',
#   'tire',
#   'unchanged',
#   'raise',
#   'est',
#   'forecast',
#   'q1',
#   'eps'],
#  ['morgan', 'stanley', 'capital', 'llc', 'form', 'eptri', 'plc'],
#  ['amc',
#   'announces',
#   'new',
#   'programming',
#   'premiere',
#   'coincide',
#   'firstever',
#   'uk',
#   'launch',
#   '28th',
#   'august',
#   'exclusively',
#   'customersfirst',
#   'episode',
#   'âeurofear',
#   'walking',
#   'deadâeurotm',
#   'shown',
#   'free',
#   'charge',
#   'showcase',
#   'freeviewamc',
#   'feature',
#   'programming',
#   'icon',
#   'film',
#   'distribution',
#   'lionsgate',
#   'miramax®',
#   'paramount',
#   'picture',
#   'sony',
#   'picture'],
#  ['global',
#   'vascular',
#   'access',
#   'device',
#   'market',
#   'key',
#   'player',
#   'becton',
#   'dickinson',
#   'co',
#   'angiodynamics',
#   'teleflex',
#   'fresenius',
#   'bbraun',
#   'melsungen'],
#  ['kryvyi',
#   'rih',
#   'accuses',
#   'kryvyi',
#   'rih',
#   'city',
#   'authority',
#   'exerting',
#   'pressure'],
#  ['uk',
#   'patent',
#   'office',
#   'published',
#   'patent',
#   'system',
#   'plc',
#   'titled',
#   'structure',
#   'navigation'],
#  ['kternai', 'app', 'available', 'trial', 'purchase', 'sap®', 'app', 'center'],
#  ['plc', 'holding', 'company'],
#  ['australia',
#   'patent',
#   'file',
#   'application',
#   'flow',
#   'apparatus',
#   'monitoring',
#   'system',
#   'relating',
#   'thereto'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'nv',
#   'plc',
#   'method',
#   'demonstrating',
#   'sebum',
#   'removal',
#   'laundered',
#   'garment',
#   'british',
#   'inventor'],
#  ['australia',
#   'sa',
#   'centre',
#   'national',
#   'de',
#   'la',
#   'recherche',
#   'scientifique',
#   'cnrs',
#   'ecole',
#   'nationale',
#   'superieure',
#   'de',
#   'chimie',
#   'de',
#   'montpellier',
#   'receive',
#   'patent',
#   'tio2',
#   'material',
#   'absorbent',
#   'visible',
#   'spectrum',
#   'method',
#   'producing'],
#  ['global',
#   'pctfe',
#   'market',
#   'growth',
#   'analysis',
#   'research',
#   'trend',
#   'demand',
#   'market',
#   'size',
#   '2020arkema',
#   'honeywell',
#   'halopolymer',
#   'dupont',
#   'etc'],
#  ['gold', 'international', 'ltd', 'annual'],
#  ['group', 'plc', 'drx', 'director', 'declaration', 'april'],
#  ['electrical',
#   'house',
#   'ehouse',
#   'market',
#   'booming',
#   'siemens',
#   'eaton',
#   'general'],
#  ['paul', 'smith', 'appointed', 'cfo', 'wintershall', 'dea'],
#  ['awardwinning',
#   'technology',
#   'jumpstart',
#   'municipal',
#   'saving',
#   'accelerating',
#   'streetlight',
#   'conversion'],
#  ['china', 'mobvoi', 'join', 'force', 'ai'],
#  ['lloyd', 'group', 'plc', 'directorpdmr'],
#  ['say', 'u', 'account', 'could', 'hacked'],
#  ['london', 'notice', 'admission', 'trading'],
#  ['military', 'federal', 'contract', 'awarded', 'system', 'land', 'armament'],
#  ['vanguard', 'group', 'form', 'anheuserbusch', 'sanv'],
#  ['prestab', 'primary', 'new', 'issue', 'stabilisation', 'notice'],
#  ['patent',
#   'office',
#   'granted',
#   'patent',
#   'fr',
#   'titled',
#   'method',
#   'system',
#   'device',
#   'securing',
#   'traffic',
#   'traffic',
#   'path',
#   'computer',
#   'network'],
#  ['top', 'news', 'group', 'private', 'equity', 'unit', 'lift', 'net'],
#  ['gavilon',
#   'bring',
#   'advanced',
#   'seed',
#   'technology',
#   'grain',
#   'marketing',
#   'confidence',
#   'corn',
#   'farmer',
#   'agrisure',
#   'duracadetm',
#   'introductory',
#   'launch',
#   'program',
#   'right',
#   'grow',
#   'offer',
#   'farmer',
#   'stepchange',
#   'corn',
#   'rootworm',
#   'control',
#   'grain',
#   'marketing',
#   'option'],
#  ['uspto',
#   'published',
#   'patent',
#   'application',
#   'bvi',
#   'limited',
#   'titled',
#   'polymer',
#   'carrying',
#   'hydroxyl',
#   'group',
#   'ester',
#   'group',
#   'method',
#   'production',
#   'thereof'],
#  ['tech',
#   'enterprise',
#   'connect',
#   'keynote',
#   'feature',
#   'industry',
#   'pioneer',
#   'ray',
#   'ozzie',
#   'plus',
#   'google',
#   'microsoft',
#   'cisco'],
#  ['growth', 'sale', 'first', 'quarter'],
#  ['fedimmutep', 'surge', 'partnership'],
#  ['spiraxsarco', 'lift', 'interim', 'dividend', 'despite', 'currency', 'hit'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'loreal',
#   'scott',
#   'straka',
#   'system',
#   'use',
#   'encoded',
#   'end',
#   'effector',
#   'related',
#   'method',
#   'use',
#   'american',
#   'inventor'],
#  ['wipo',
#   'publishes',
#   'patent',
#   'koninklijke',
#   'network',
#   'collaborating',
#   'device',
#   'inventor'],
#  ['coloplasts',
#   'clpbf',
#   'ceo',
#   'lars',
#   'rasmussen',
#   'q2',
#   'result',
#   'earnings',
#   'call',
#   'transcript'],
#  ['elliott',
#   'capital',
#   'advisor',
#   'lp',
#   'elliott',
#   'capital',
#   'advisor',
#   'lp',
#   'form',
#   'sky',
#   'plc',
#   'public',
#   'opening',
#   'position',
#   'disclosuredealing',
#   'disclosure',
#   'person',
#   'interest',
#   'relevant',
#   'representing'],
#  ...]

# %%
from keras.preprocessing.text import Tokenizer
# prepare tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
vocab_size = len(tokenizer.word_index) + 1

# %%
cd
# Out:
# /Users/Artur

# %%
stop_words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07be5ff4bce8> in <module>
# ----> 1 stop_words
#
# NameError: name 'stop_words' is not defined

# %%
# write away results
results_all_df.to_csv('./Output/Model performance/results_embeddings.csv', index = False, header = True)

# %%
# Write the dictionary with the best parameters away
with open('./Output/parameters/embeddings.json', 'w') as file:
    json.dump(best_params_dict, file)
